# %% [markdown]
# **Web Scraping und Data Mining in Python**
#
# # Webscraping and Webcrawling
#
#
# Jan Riebling, *Universität Wuppertal*

# %% [markdown]
# # Einführung ins web scraping

# %% [markdown]
# ## Screen scraping
#
# Daten vom Bildschirm „abkratzen“, d.h. Daten die dem Nutzer angezeigt werden. Da von Browsern dargestellte HTML-Dokumente eine der meistgenutzten Datenquellen sind, spricht man auch vom „web scraping“.

# %% [markdown]
# ## Downloading
#
# Python 3's `urllib` Modul stellt Funktionen und Klassen für das Öffnen und Herunterladen von Online-Ressourcen bereit. Ein tieferer Einblick findet sich in der Python Dokumentation und dem darin enthaltenen [How To](https://docs.python.org/3/howto/urllib2.html).

# %%
import urllib

url = 'https://www.uni-mainz.de/'

# To be on the safe side:
with urllib.request.urlopen(url) as response:
    html = response.read()

# %%
print(html[:1500])
# Out:
# b'<!DOCTYPE html>\r\n<html dir="ltr" lang="de">\r\n   <head>\r\n      <meta charset="utf-8">\r\n      <meta http-equiv="X-UA-Compatible" content="IE=edge">\r\n      <meta name="viewport" content="width=device-width, initial-scale=1.0">      <meta name="author" content="Johannes Gutenberg-Universit\xc3\xa4t Mainz">\r\n      <meta name="description" content="Die Johannes Gutenberg-Universit\xc3\xa4t Mainz z\xc3\xa4hlt mit rund 33.000 Studierenden aus \xc3\xbcber 130 Nationen zu den zehn gr\xc3\xb6\xc3\x9ften Universit\xc3\xa4ten Deutschlands. Als einzige Volluniversit\xc3\xa4t in Rheinland-Pfalz vereint sie nahezu alle akademischen Disziplinen.">\r\n      <meta name="page_id" content="2">\r\n      <meta name="copyright" content="Johannes Gutenberg-Universit\xc3\xa4t Mainz">\r\n      <meta name="Linktitle" content="">\r\n      <meta name="keywords" content="">\r\n      <meta name="robots" content="index, follow, noarchive">\r\n      <meta name="generator" content="">\r\n      <title>\r\n         Willkommen an der JGU!\r\n      </title>\r\n      <link rel="shortcut icon" href="/Illustrationen/favicon.ico">\r\n      <link rel="icon" href="/Illustrationen/favicon.ico"><link rel="canonical" href="http://www.uni-mainz.de/index.php">\r\n      <!-- CSS-Base-URL ist css.uni-mainz.de -->\r\n      <link href="//css.uni-mainz.de/css/jgu_style.min.css?v=1571842591" rel="stylesheet">\r\n      <!--[if lt IE 9]>\r\n        <script src="//css.uni-mainz.de/js/html5shiv.min.js"></script>\r\n        <script src="//css.uni-mainz.de/js/respond.min.js"></script>\r\n      <![endif]-->\r\n      <script s'

# %% [markdown]
# ## Hypertext Markup Language
#
# Beschreibt die Semantik eines HTML-Dokuments. Besteht aus einem *Baum* einzelner HTML-Elemente. Jedes Element besteht aus drei Teilen:
#
# ```html
# <a href="https://www.wikipedia.org/">A link to Wikipedia!</a>
# ```
#
# 1. Die *Tags*, die das Element eröffnen und schließen.
# 2. Die *Attribute* des Elements, die sich innerhalb des eröffnenden Tags finden.
# 3. Der *Text* der „marked up“ werden soll.

# %% [markdown]
# <a href="https://www.wikipedia.org/">A link to Wikipedia!</a>

# %% [markdown]
# # BeautifulSoup

# %% [markdown]
# ## Parsing HTML
#
# Der Vorgang des Analysierens und Prozessierens einer Zeichenkette nach den Regeln einer formalen Grammatik. Das resultierende Objekt ist meistens eine hierarchische Repräsentation des Strings in Form eines Baumgraphens.

# %% [markdown]
# ## Wie?
#
# BeautifulSoup ist ein Python Paket, welches es erlaubt HTML und XML-Strings zu parsen und auf diese als native Python-Typen zuzugreifen. Die Dokumentation fimndet sich [hier](http://www.crummy.com/software/BeautifulSoup/bs4/doc/#).

# %%
from bs4 import BeautifulSoup

# Parsen des HTMLs der Universitäts-Webseite
soup = BeautifulSoup(html, 'html5lib')

# %% [markdown]
# ## Den Wald vor lauter Bäumen...
#
# Bei Baum-Graphen handelt es sich um gerichtete Graphen, d.h. Knoten die mit Kantenzügen verbunden sind die eine Richtung aufweisen. Sie gehen von einem Ursprung aus (Root) und dürfen keine Kreise, im graphtheoretischen Sinne des Wortes enthalten. Ausführlichere Informationen finden sich [hier](https://en.wikipedia.org/wiki/Tree_%28data_structure%29).

# %% [markdown]
# ## Ein Baum:
#
# ![A tree](https://upload.wikimedia.org/wikipedia/commons/thumb/f/f7/Binary_tree.svg/300px-Binary_tree.svg.png)

# %% [markdown]
# ## Kein Baum:
#
# ![Not a tree](https://upload.wikimedia.org/wikipedia/commons/thumb/1/1c/Directed_graph%2C_cyclic.svg/320px-Directed_graph%2C_cyclic.svg.png)

# %% [markdown]
# ## Terminologie
#
# * **Root**: the top parent node.
# * **Parent**: node with outgoing edge relative to the child.
# * **Child**: node with incoming edge relative to the parent.
# * **Siblings**: nodes with the same parent.
# * **Descendants**: all nodes reachable from a parent node.
# * **Ancestors**: all parents of a specific child node.
#
# ![A tree](https://upload.wikimedia.org/wikipedia/commons/thumb/f/f7/Binary_tree.svg/300px-Binary_tree.svg.png)

# %% [markdown]
# ## Bäume navigieren

# %%
soup
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="de"><head>
#       <meta charset="utf-8"/>
#       <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#       <meta content="width=device-width, initial-scale=1.0" name="viewport"/>      <meta content="Johannes Gutenberg-Universität Mainz" name="author"/>
#       <meta content="Die Johannes Gutenberg-Universität Mainz zählt mit rund 33.000 Studierenden aus über 130 Nationen zu den zehn größten Universitäten Deutschlands. Als einzige Volluniversität in Rheinland-Pfalz vereint sie nahezu alle akademischen Disziplinen." name="description"/>
#       <meta content="2" name="page_id"/>
#       <meta content="Johannes Gutenberg-Universität Mainz" name="copyright"/>
#       <meta content="" name="Linktitle"/>
#       <meta content="" name="keywords"/>
#       <meta content="index, follow, noarchive" name="robots"/>
#       <meta content="" name="generator"/>
#       <title>
#          Willkommen an der JGU!
#       </title>
#       <link href="/Illustrationen/favicon.ico" rel="shortcut icon"/>
#       <link href="/Illustrationen/favicon.ico" rel="icon"/><link href="http://www.uni-mainz.de/index.php" rel="canonical"/>
#       <!-- CSS-Base-URL ist css.uni-mainz.de -->
#       <link href="//css.uni-mainz.de/css/jgu_style.min.css?v=1571842591" rel="stylesheet"/>
#       <!--[if lt IE 9]>
#         <script src="//css.uni-mainz.de/js/html5shiv.min.js"></script>
#         <script src="//css.uni-mainz.de/js/respond.min.js"></script>
#       <![endif]-->
#       <script src="//css.uni-mainz.de/js/jquery_bootstrap.min.js?v=1475065122"></script>      <script src="//scripts.zdv.uni-mainz.de/js/js_lib_neu.min.js" type="text/javascript">
#       </script>
#       <link href="/32.php" rel="alternate" title="RSS-Feed" type="application/rss+xml"/>
#    </head>   <body class="grau">
#       <a id="page_start"></a>       <div class="container">
#                   <header id="header_big">
#             <a href="//www.uni-mainz.de" target="_top"><span class="jgu_logo_image" id="jgu_logo" title="Johannes Gutenberg-Universität Mainz"></span>
#             </a><div class="sr-only"><a href="//www.uni-mainz.de" target="_top">
#                </a><a href="//www.uni-mainz.de" target="_top"><span class="jgu_logo_image" id="jgu_logo" title="Johannes Gutenberg-Universität Mainz">Logo der Johannes Gutenberg-Universität Mainz</span></a>
#             </div> <a href="/index.php"></a>
#          </header>
#          <header class="row" id="header_small">
#             <div class="col-xs-2">
#                <a href="//www.uni-mainz.de" target="_top"><span class="jgu_logo_small" id="jgu_logo_small" title="Johannes Gutenberg-Universität Mainz"></span>
#                </a><div class="sr-only"><a href="//www.uni-mainz.de" target="_top">
#                   </a><a href="//www.uni-mainz.de" target="_top"><span class="jgu_logo_small" id="jgu_logo_small" title="Johannes Gutenberg-Universität Mainz">Logo der Johannes Gutenberg-Universität Mainz</span></a>
#                </div>
#             </div>
#             <div class="col-xs-8 text-center"></div>
#             <div class="col-xs-2 text-right">
#                <nav id="nav_toggle">
#                   <a accesskey="5" class="collapsed" data-target="#nav_mobile" data-toggle="collapse" href="#" title="Enter navigation"><span class="icon_mobile_nav icon_bars"><dfn class="sr-only">Navigation ein-/ausblenden</dfn></span></a>
#                </nav>
#             </div>
#          </header>         <nav id="nav_meta">
#             <ul class="list-inline">
#                <li class="icon icon_home">
#                   <a accesskey="1" href="/index.php" target="_top" title="Startseite dieser Website">Home</a>
#                </li>
#                <li class="icon icon_search">
#                   <a accesskey="5" data-target="#searchbar" data-toggle="collapse" href="http://www.uni-mainz.de/suche" target="_top" title="Suche">Suche</a>
#                </li>
#                <li class="icon icon_contact">
#                   <a href="http://www.uni-mainz.de/kontakt" target="_top" title="Kontakt">Kontakt</a>
#                </li><!-- Sprachenlinks -->
#                <li class="icon icon_language">
#                   <a href="/eng/index.php" target="_top" title="This page in English">English</a>
#                </li>
#             </ul>
#          </nav><!-- JSON-L1Menu --><!-- [{"url":"https://universitaet.uni-mainz.de","text":"Über die JGU","active":"","target":"","ebene":"2","position":"1","parent_position":"0"},{"url":"https://organisation.uni-mainz.de","text":"Organisation","active":"","target":"","ebene":"2","position":"2","parent_position":"0"},{"url":"https://fachbereiche.uni-mainz.de/","text":"Fachbereiche","active":"","target":"","ebene":"2","position":"3","parent_position":"0"},{"url":"https://www.studium.uni-mainz.de/","text":"Studium","active":"","target":"","ebene":"2","position":"4","parent_position":"0"},{"url":"https://lehre.uni-mainz.de","text":"Lehre","active":"","target":"","ebene":"2","position":"5","parent_position":"0"},{"url":"https://forschungsprofil.uni-mainz.de","text":"Forschung","active":"","target":"","ebene":"2","position":"6","parent_position":"0"},{"url":"https://wissenschaftliche-weiterbildung.uni-mainz.de","text":"Weiterbildung","active":"","target":"","ebene":"2","position":"7","parent_position":"0"}] --><!-- JSON-L1Menu --><!-- JSON-LinkeSpalte --><!-- [] --><!-- JSON-LinkeSpalte -->
#          <nav id="nav_main">
#             <!-- Level-1-Menue -->
#             <ul class="sf-menu list-inline">
#                <li class="main">
#                   <a class="" href="https://universitaet.uni-mainz.de" title="Über die JGU">Über die JGU</a>
#                </li>
#                <li class="main">
#                   <a class="" href="https://organisation.uni-mainz.de" title="Organisation">Organisation</a>
#                </li>
#                <li class="main">
#                   <a class="" href="https://fachbereiche.uni-mainz.de/" title="Fachbereiche">Fachbereiche</a>
#                </li>
#                <li class="main">
#                   <a class="" href="https://www.studium.uni-mainz.de/" title="Studium">Studium</a>
#                </li>
#                <li class="main">
#                   <a class="" href="https://lehre.uni-mainz.de" title="Lehre">Lehre</a>
#                </li>
#                <li class="main">
#                   <a class="" href="https://forschungsprofil.uni-mainz.de" title="Forschung">Forschung</a>
#                </li>
#                <li class="main">
#                   <a class="" href="https://wissenschaftliche-weiterbildung.uni-mainz.de" title="Weiterbildung">Weiterbildung</a>
#                </li>
#             </ul><!-- Level-1-Menue -->
#          </nav><!--  Mobile Navigation -->
#          <div class="hidden-md hidden-lg hidden-sm collapse.in" id="nav_mobile">
#             <!-- Metanavigation -->
#             <nav class="col-xs-12" id="nav_meta_mobile">
#                <ul class="list-inline">
#                   <li class="icon icon_home">
#                      <a accesskey="1" href="/index.php" target="_top" title="Startseite dieser Website">Home</a>
#                   </li>
#                   <li class="icon icon_search">
#                      <a accesskey="5" data-target="#searchbar" data-toggle="collapse" href="http://www.uni-mainz.de/suche" target="_top" title="Suche">Suche</a>
#                   </li>
#                   <li class="icon icon_contact">
#                      <a href="http://www.uni-mainz.de/kontakt" target="_top" title="Kontakt">Kontakt</a>
#                   </li><!-- Sprachenlinks -->
#                   <li class="icon icon_language">
#                      <a href="/eng/index.php" target="_top" title="This page in English">English</a>
#                   </li>
#                </ul>
#             </nav><!-- CORE NAVIGATION -->
#             <ul class="nav nav-tabs" id="nav_mobile_tabs" role="tablist">
#                <li class="active">
#                   <a data-toggle="tab" href="#menu2" role="tab">Site Links</a>
#                </li>
#             </ul>
#             <div class="tab-content">
#                <div class="tab-pane fade active in" id="menu2">
#                   <nav id="nav_left_mobile">
#                      <ul>
#                         <li class="menueebene2off">
#                            <a class="" href="https://universitaet.uni-mainz.de" title="Über die JGU">Über die JGU</a>
#                         </li>
#                         <li class="menueebene2off">
#                            <a class="" href="https://organisation.uni-mainz.de" title="Organisation">Organisation</a>
#                         </li>
#                         <li class="menueebene2off">
#                            <a class="" href="https://fachbereiche.uni-mainz.de/" title="Fachbereiche">Fachbereiche</a>
#                         </li>
#                         <li class="menueebene2off">
#                            <a class="" href="https://www.studium.uni-mainz.de/" title="Studium">Studium</a>
#                         </li>
#                         <li class="menueebene2off">
#                            <a class="" href="https://lehre.uni-mainz.de" title="Lehre">Lehre</a>
#                         </li>
#                         <li class="menueebene2off">
#                            <a class="" href="https://forschungsprofil.uni-mainz.de" title="Forschung">Forschung</a>
#                         </li>
#                         <li class="menueebene2off">
#                            <a class="" href="https://wissenschaftliche-weiterbildung.uni-mainz.de" title="Weiterbildung">Weiterbildung</a>
#                         </li>
#                      </ul>
#                   </nav>
#                </div>
#             </div><!-- tab-content -->
#          </div><!-- Ende div #navigation -->
#          <!-- Hier kommt der Seiteninhalt, ggf. in Spalten -->
#          <main class="container editorcontent" role="main">
#             <div class="jgu_homepage_slider row">
#                <div class="col-sm-8 col-md-8">
#                   <noscript>
#                   <div class="image">
#                      <div class="subtitle">
#                         Bitte beachten: zur Nutzung dieser Website empfehlen wir die Aktivierung von Javascript in Ihrem Browser.
#                      </div>
#                   </div></noscript>
#                   <div class="carousel slide lazy" data-interval="false" id="jgu_carousel_id_50" style="max-width:65.15625em;">
#                      <div class="carousel-inner" role="listbox">
#                         <div class="item active">
#                            <a href="https://www.studium.uni-mainz.de/einfuehrungsveranstaltungen/"><img alt="Informationsangebote für Erstsemester zum Sommersemester 2022 (Grafik: artefont – Tanja Labs) ...&gt;" class="slide1" src="/Bilder_allgemein/startseite_ZSB_ersti-veranstaltungen_sose_2022_rdax_836x334.jpg"/></a>
#                            <div class="carousel-caption">
#                               <a href="https://www.studium.uni-mainz.de/einfuehrungsveranstaltungen/">Informationsangebote für Erstsemester zum Sommersemester 2022 (Grafik: artefont – Tanja Labs) ...&gt;</a>
#                            </div><!--  -->
#                         </div>
#                         <div class="item">
#                            <a href="https://www.uni-mainz.de/presse/aktuell/13679_DEU_HTML.php"><img alt="Mit dem neuen Sonderforschungsbereich TPChange unter Leitung von Prof. Dr. Peter Hoor (r.) untersucht die JGU die Bedeutung der Tropopausenregion für das Klima (Foto: Eric Lichtenscheidt)" class="slide2" data-src="/Bilder_allgemein/SFB_301_TPChange_25_Foto_Eric_Lichtenscheidt.jpg" src=""/></a>
#                            <div class="carousel-caption">
#                               <a href="https://www.uni-mainz.de/presse/aktuell/13679_DEU_HTML.php">Mit dem neuen Sonderforschungsbereich TPChange unter Leitung von Prof. Dr. Peter Hoor (r.) untersucht die JGU die Bedeutung der Tropopausenregion für das Klima (Foto: Eric Lichtenscheidt)</a>
#                            </div><!--  -->
#                         </div>
#                         <div class="item">
#                            <a href="https://www.studium.uni-mainz.de/studienwahl-podcast/"><img alt="Du bist noch auf der Suche nach dem passenden Studiengang? Dann einfach reinhören in unseren Studienwahl-Podcast!" class="slide3" data-src="/Bilder_allgemein/startseite_ZSB_studienwahlpodcast_836x334.jpg" src=""/></a>
#                            <div class="carousel-caption">
#                               <a href="https://www.studium.uni-mainz.de/studienwahl-podcast/">Du bist noch auf der Suche nach dem passenden Studiengang? Dann einfach reinhören in unseren Studienwahl-Podcast!</a>
#                            </div><!--  -->
#                         </div>
#                         <div class="item">
#                            <a href="https://gutenberg-netzwerk.uni-mainz.de/projekte/75aus75"><img alt="Lernen Sie 75 Gutenberg-Alumni aus 75 Jahren JGU kennen! (Fotos/© v.l.: HHU / Ivo Mayr, Laurence Chaperon, Stefanie Aumiller / MPG, privat, Frieder Scheuschner, privat, privat, Hwang philjoo) " class="slide4" data-src="/Bilder_allgemein/75aus75_banner_startseite_v03.jpg" src=""/></a>
#                            <div class="carousel-caption">
#                               <a href="https://gutenberg-netzwerk.uni-mainz.de/projekte/75aus75">Lernen Sie 75 Gutenberg-Alumni aus 75 Jahren JGU kennen! (Fotos/© v.l.: HHU / Ivo Mayr, Laurence Chaperon, Stefanie Aumiller / MPG, privat, Frieder Scheuschner, privat, privat, Hwang philjoo)</a>
#                            </div><!--  -->
#                         </div>
#                         <div class="carousel-controls row">
#                            <div class="col-sm-2 col-md-2 col-xs-2 text-left carousel-control-left">
#                               <a class="left carousel-control carousel-control-area-left" data-slide="prev" href="#jgu_carousel_id_50" role="button"><dfn class="sr-only">Zurück</dfn></a>
#                            </div>
#                            <div class="col-sm-8 col-md-8 col-xs-8">
#                               <!-- Positionsanzeige -->
#                               <ol class="carousel-indicators">
#                                  <li class="active" data-slide-to="0" data-target="#jgu_carousel_id_50">
#                                     <dfn class="sr-only">Zu Bild 'Informationsangebote für Erstsemester zum Sommersemester 2022 (Grafik: artefont – Tanja Labs) ...&gt;'</dfn>
#                                  </li><!--  -->
#                                  <li data-slide-to="1" data-target="#jgu_carousel_id_50">
#                                     <dfn class="sr-only">Zu Bild 'Mit dem neuen Sonderforschungsbereich TPChange unter Leitung von Prof. Dr. Peter Hoor (r.) untersucht die JGU die Bedeutung der Tropopausenregion für das Klima (Foto: Eric Lichtenscheidt)'</dfn>
#                                  </li><!--  -->
#                                  <li data-slide-to="2" data-target="#jgu_carousel_id_50">
#                                     <dfn class="sr-only">Zu Bild 'Du bist noch auf der Suche nach dem passenden Studiengang? Dann einfach reinhören in unseren Studienwahl-Podcast!'</dfn>
#                                  </li><!--  -->
#                                  <li data-slide-to="3" data-target="#jgu_carousel_id_50">
#                                     <dfn class="sr-only">Zu Bild 'Lernen Sie 75 Gutenberg-Alumni aus 75 Jahren JGU kennen! (Fotos/© v.l.: HHU / Ivo Mayr, Laurence Chaperon, Stefanie Aumiller / MPG, privat, Frieder Scheuschner, privat, privat, Hwang philjoo) '</dfn>
#                                  </li><!--  -->
#                               </ol>
#                            </div>
#                            <div class="col-sm-2 col-md-2 col-xs-2 text-right carousel-control-right">
#                               <a class="right carousel-control carousel-control-area-right" data-slide="next" href="#jgu_carousel_id_50" role="button"><dfn class="sr-only">Vor</dfn></a>
#                            </div>
#                         </div>
#                      </div>
#                   </div>
#                </div>
#                <div class="col-sm-4 col-md-4">
#                   <!-- Google CSE Search Box Begins -->
#                                     <div class="jgu_widget jgu_quicksearch">
#                      <form action="https://scripts.zdv.uni-mainz.de/suche/suche_metager.php" id="google_suchbox" method="post" name="google_suchbox">
#                         <fieldset class="group">
#                            <legend>Inhalte durchsuchen</legend> <label for="jgu_googlebox">Suche</label> <input class="text" id="jgu_googlebox" maxlength="50" name="q" onfocus="document.google_suchbox.q.value = ''" placeholder="Suche" type="text" value=" "/> <button class="submit" id="jgu_googlesubmit" title="Los" type="submit">Los</button> <span></span>
#                         </fieldset><input name="handler" type="hidden" value="web-crawler"/> <input name="output" type="hidden" value="xml_no_dtd"/> <input name="filter" type="hidden" value="0"/> <input name="getfields" type="hidden" value="description"/> <input name="sitesearch" type="hidden" value="www.uni-mainz.de"/>
#                      </form><!-- Anfang: Nur anzeigen wenn Suchlinks definiert sind -->
#                      <ul class="links">
#                         <li>
#                            <a href="https://jogustine.uni-mainz.de/">JOGU-StINe</a>
#                         </li>
#                         <li>
#                            <a href="https://personen.uni-mainz.de/">Personensuche</a>
#                         </li>
#                      </ul><!-- Ende: Nur anzeigen wenn Suchlinks definiert sind -->
#                   </div><!-- /#quicksearch -->
#                   <!-- Anfang: Nur anzeigen wenn Toplinks definiert sind -->
#                   <div class="jgu_widget jgu_homepage_toplinks">
#                      <h2>
#                         Toplinks
#                      </h2>
#                      <ul>
#                         <li class="row">
#                            <a class="group" href="http://www.studium.uni-mainz.de/"><img alt="STUDIEREN AN DER JGU" class="right" src="/Bilder_allgemein/banner_portal_studium_190pxbreit.jpg"/><strong>STUDIEREN AN DER JGU:</strong> <nobr>250 Studiengänge</nobr> entdecken im Portal Studium</a>
#                         </li>
#                         <li class="row">
#                            <a class="group" href="http://www.international.uni-mainz.de"><strong>JGU INTERNATIONAL:</strong> Global vernetzt in Wissenschaft und Forschung, Studium und Lehre</a>
#                         </li>
#                         <li class="row">
#                            <a class="group" href="https://karriere.uni-mainz.de/"><strong>KARRIERE AN DER JGU:</strong> Bewerben Sie sich jetzt bei einer der größten Universitäten Deutschlands.</a>
#                         </li>
#                      </ul>
#                   </div><!-- /#homepage_toplinks -->
#                   <!-- Ende: Nur anzeigen wenn Toplinks definiert sind -->
#                </div>
#             </div>            <div id="jgu_targetaudience">
#                <div id="nav_targetaudience">
#                   <ul>
#                      <li id="nav_targetaudience_link_1">
#                         <a href="/index.php">Studieninteressierte</a>
#                      </li>
#                      <li id="nav_targetaudience_link_2">
#                         <a href="/index.php">Studierende</a>
#                      </li>
#                      <li id="nav_targetaudience_link_3">
#                         <a href="/index.php">Wiss. Nachwuchs</a>
#                      </li>
#                      <li id="nav_targetaudience_link_4">
#                         <a href="/index.php">Wissenschaftler/-innen</a>
#                      </li>
#                      <li id="nav_targetaudience_link_5">
#                         <a href="/index.php">Beschäftigte</a>
#                      </li>
#                      <li id="nav_targetaudience_link_6">
#                         <a href="/index.php">Gutenberg-Alumni</a>
#                      </li>
#                      <li id="nav_targetaudience_link_7">
#                         <a href="/index.php">Förderer</a>
#                      </li>
#                      <li id="nav_targetaudience_link_8">
#                         <a href="/index.php">Unternehmen</a>
#                      </li>
#                      <li class="active" id="nav_targetaudience_link_9">
#                         <a href="/index.php">Presse</a>
#                      </li>
#                   </ul>
#                </div><!-- /#nav_targetaudience -->
#                <script type="text/javascript">
#                /*-- ein und Ausblenden der Links --*/
#                jQuery.fn.nav_targetaudience_link = function(name) {
#                var name = name;
#                $("#nav_targetaudience_link_"+name+" a").click(function(event){
#                event.preventDefault();
#                $(".nav_targetaudience_content:not(#nav_targetaudience_content_"+name+")").css( "display", "none" );
#                         /* Darstellung des aktiven Feldes in Targetnavigation */
#                         $("#nav_targetaudience li").removeClass("active");
#                $("#nav_targetaudience_link_"+name).addClass("active");
#                $("#nav_targetaudience_content_"+name).css("display", "");
#                });
#                };
#                /*-- Steuerung für den Switch zwischen den Links --*/
#                $(document).ready(function(){
#                $('#nav_targetaudience li').each(function(index) {
#                var linkid = $(this).attr('id');
#                var contentname = linkid.replace('nav_targetaudience_link_', '');
#                $('#' + linkid).nav_targetaudience_link(contentname);
#                });
#                });
#                </script>                <div class="row row-flex row-flex-wrap colored nav_targetaudience_content" id="nav_targetaudience_content_1" style="display: none;">
#                   <!-- in class:  -->
#                   <!-- ausserhalb von class:  -->
#                   <div class="col-sm-4 col-md-4 col-xs-12" style="margin-right: 0.2em;">
#                      <div class="nav_targetaudience_header content teaserlist nav_targetaudience_colored">
#                         <div class="row">
#                            <h2>
#                               STUDIENORIENTIERUNG
#                            </h2>
#                         </div>
#                         <div class="row teaser">
#                            <p></p><!-- Bilddarstellung -->
#                            <a class="bildlink" href="https://www.studium.uni-mainz.de/hochschulmessen/"><img alt="Kleines Bild" class="left" src="/Illustrationen/Studium_Messen_150x100.jpg" title="Kleines Bild"/></a> <!-- Überschrift -->
#                            <h3>
#                               <a href="https://www.studium.uni-mainz.de/hochschulmessen/">Die JGU auf Hochschulmessen</a>
#                            </h3><!-- Teasertext und Link mehr -->
#                            <p>
#                               Sie möchten die JGU und ihr umfangreiches Studienangebot kennenlernen? Das Team der Zentralen Studienberatung vertritt die JGU auf zahlreichen Hochschulmessen in ganz Deutschland. Bestimmt auch in Ihrer Nähe.
#                               <br/>
#                               <a class="detaillink" href="https://www.studium.uni-mainz.de/hochschulmessen/">mehr</a>
#                            </p>
#                         </div>
#                         <div class="row teaser">
#                            <p></p><!-- Bilddarstellung -->
#                            <a class="bildlink" href="https://www.studium.uni-mainz.de/studienorientierung/"><img alt="Kleines Bild" class="left" src="/Illustrationen/studium_herbstuni_150x100.jpg" title="Kleines Bild"/></a> <!-- Überschrift -->
#                            <h3>
#                               <a href="https://www.studium.uni-mainz.de/studienorientierung/">Angebote zur Studienorientierung</a>
#                            </h3><!-- Teasertext und Link mehr -->
#                            <p>
#                               Es gibt viele Möglichkeiten, dass passende Studium für sich zu entdecken. Einige sogar direkt an der JGU.
#                               <br/>
#                               <a class="detaillink" href="https://www.studium.uni-mainz.de/studienorientierung/">mehr</a>
#                            </p>
#                         </div>
#                         <div class="row">
#                            <a class="listlink" href="http://www.studium.uni-mainz.de">ZUM PORTAL STUDIUM</a>
#                         </div>
#                      </div><!-- /.teaserlist -->
#                   </div>
#                   <div class="col-sm-4 col-md-4 col-xs-12" style="margin-left: 0.2em; margin-right: 0.2em;">
#                      <div class="nav_targetaudience_header content teaserlist nav_targetaudience_colored">
#                         <div class="row">
#                            <h2>
#                               STUDIENANGEBOT &amp; BEWERBUNG
#                            </h2>
#                         </div>
#                         <div class="row teaser">
#                            <p></p><!-- Bilddarstellung -->
#                            <a class="bildlink" href="http://www.uni-mainz.de/studium/99_DEU_HTML.php"><img alt="Kleines Bild" class="left" src="/Illustrationen/studium_studienangebot_150x100.jpg" title="Kleines Bild"/></a> <!-- Überschrift -->
#                            <h3>
#                               <a href="http://www.uni-mainz.de/studium/99_DEU_HTML.php">Zum Studienangebot</a>
#                            </h3><!-- Teasertext und Link mehr -->
#                            <p>
#                               Die JGU bietet mit 145 Fächern, 119 Bachelor- und 96 Masterstudiengängen eine außergewöhnlich breite Palette von Studienmöglichkeiten.
#                               <br/>
#                               <a class="detaillink" href="http://www.uni-mainz.de/studium/99_DEU_HTML.php">mehr</a>
#                            </p>
#                         </div>
#                         <div class="row teaser">
#                            <p></p><!-- Bilddarstellung -->
#                            <a class="bildlink" href="http://www.uni-mainz.de/studium/473_DEU_HTML.php"><img alt="Kleines Bild" class="left" src="/Illustrationen/studium_bewerbung_150x100.jpg" title="Kleines Bild"/></a> <!-- Überschrift -->
#                            <h3>
#                               <a href="http://www.uni-mainz.de/studium/473_DEU_HTML.php">Bewerbung um einen Studienplatz</a>
#                            </h3><!-- Teasertext und Link mehr -->
#                            <p>
#                               Sie möchten an der JGU studieren? Prima! Hier bekommen Sie alle relevanten Informationen zum Bewerbungsverfahren.
#                               <br/>
#                               <a class="detaillink" href="http://www.uni-mainz.de/studium/473_DEU_HTML.php">mehr</a>
#                            </p>
#                         </div>
#                         <div class="row">
#                            <a class="listlink" href="http://www.uni-mainz.de/studium/index.php">ZUM PORTAL STUDIUM</a>
#                         </div>
#                      </div><!-- /.teaserlist -->
#                   </div>
#                   <div class="col-sm-4 col-md-4 col-xs-12" style="margin-left: 0.2em;">
#                      <div class="nav_targetaudience_header content teaserlist nav_targetaudience_colored">
#                         <div class="row">
#                            <h2>
#                               INFORMATION UND BERATUNG
#                            </h2>
#                         </div>
#                         <div class="row teaser">
#                            <p></p><!-- Bilddarstellung -->
#                            <a class="bildlink" href="http://www.uni-mainz.de/studium/index.php"><img alt="Kleines Bild" class="left" src="/Illustrationen/studium_studierende_01_150x100.gif" title="Kleines Bild"/></a> <!-- Überschrift -->
#                            <h3>
#                               <a href="http://www.uni-mainz.de/studium/index.php">Sie interessieren sich für ein Studium an der JGU?</a>
#                            </h3><!-- Teasertext und Link mehr -->
#                            <p>
#                               Besuchen Sie unser PORTAL STUDIUM. Hier finden Sie Tipps zu Studienwahl, Bewerbungsverfahren und einen gelungenen Studieneinstieg.
#                               <br/>
#                               <a class="detaillink" href="http://www.uni-mainz.de/studium/index.php">mehr</a>
#                            </p>
#                         </div>
#                         <div class="row teaser">
#                            <p></p><!-- Bilddarstellung -->
#                            <a class="bildlink" href="http://www.uni-mainz.de/studium/400_DEU_HTML.php"><img alt="Kleines Bild" class="left" src="/Illustrationen/studium_beratung_01_150x100.jpg" title="Kleines Bild"/></a> <!-- Überschrift -->
#                            <h3>
#                               <a href="http://www.uni-mainz.de/studium/400_DEU_HTML.php">Sie suchen Ansprechpartner an der JGU?</a>
#                            </h3><!-- Teasertext und Link mehr -->
#                            <p>
#                               Mit einem Studium hängen viele Fragen zusammen. Nutzen Sie diese Angebote, werden Sie aktiv und suchen Sie die Ansprechpartner/innen auf, die Ihnen bei Ihrem Anliegen weiterhelfen können. Hier finden Sie alle relevanten Informationen.
#                               <br/>
#                               <a class="detaillink" href="http://www.uni-mainz.de/studium/400_DEU_HTML.php">mehr</a>
#                            </p>
#                         </div>
#                         <div class="row">
#                            <a class="listlink" href="http://www.uni-mainz.de/studium/index.php">ZUM PORTAL STUDIUM</a>
#                         </div>
#                      </div><!-- /.teaserlist -->
#                   </div>
#                </div><!-- /#nav_targetaudience_content_home -->
#                <!-- Studieninteressierte -->
#                <div class="row row-flex row-flex-wrap colored nav_targetaudience_content" id="nav_targetaudience_content_2" style="display: none;">
#                   <!-- in class:  -->
#                   <!-- ausserhalb von class:  -->
#                   <div class="col-sm-4 col-md-4 col-xs-12" style="margin-right: 0.2em;">
#                      <div class="nav_targetaudience_header content teaserlist nav_targetaudience_colored">
#                         <div class="row">
#                            <h2>
#                               AKTUELLES
#                            </h2>
#                         </div>
#                         <div class="row teaser">
#                            <p></p><!-- Bilddarstellung -->
#                            <a class="bildlink" href="https://sl.uni-mainz.de/information-zum-umgang-der-jgu-mit-dem-coronavirus/"><img alt="Kleines Bild" class="left" src="/Illustrationen/studium_corona_150x100.jpg" title="Kleines Bild"/></a> <!-- Überschrift -->
#                            <h3>
#                               <a href="https://sl.uni-mainz.de/information-zum-umgang-der-jgu-mit-dem-coronavirus/">Informationen zur Coronapandemie</a>
#                            </h3><!-- Teasertext und Link mehr -->
#                            <p>
#                               Die aktuelle Entwicklung der Coronavirus-Pandemie hat weitreichende Folgen für den Lehr-, Studien- und Prüfungsbetrieb im Sommersemester 2020 an der JGU. Hier finden Sie grundlegende Informationen über Entscheidungen und Maßnahmen.
#                               <br/>
#                               <a class="detaillink" href="https://sl.uni-mainz.de/information-zum-umgang-der-jgu-mit-dem-coronavirus/">mehr</a>
#                            </p>
#                         </div>
#                         <div class="row teaser">
#                            <p></p><!-- Bilddarstellung -->
#                            <a class="bildlink" href="https://www.studium.uni-mainz.de"><img alt="Kleines Bild" class="left" src="/Illustrationen/studium_online-bewerbung_01_150x100.jpg" title="Kleines Bild"/></a> <!-- Überschrift -->
#                            <h3>
#                               <a href="https://www.studium.uni-mainz.de">Portal Studium</a>
#                            </h3><!-- Teasertext und Link mehr -->
#                            <p>
#                               Hier finden Sie alle relevanten Informationen rund ums Studium.
#                               <br/>
#                               <a class="detaillink" href="https://www.studium.uni-mainz.de">mehr</a>
#                            </p>
#                         </div>
#                         <div class="row">
#                            <a class="listlink" href="http://www.uni-mainz.de/studium/95_DEU_HTML.php">ZUM PORTAL STUDIUM</a>
#                         </div>
#                      </div><!-- /.teaserlist -->
#                   </div>
#                   <div class="col-sm-4 col-md-4 col-xs-12" style="margin-left: 0.2em; margin-right: 0.2em;">
#                      <div class="nav_targetaudience_header content teaserlist nav_targetaudience_colored">
#                         <div class="row">
#                            <h2>
#                               STUDIUM AN DER JGU
#                            </h2>
#                         </div>
#                         <div class="row teaser">
#                            <p></p><!-- Bilddarstellung -->
#                            <a class="bildlink" href="http://www.uni-mainz.de/studium/95_DEU_HTML.php"><img alt="Kleines Bild" class="left" src="/Illustrationen/studium_jogustine_150x100.jpg" title="Kleines Bild"/></a> <!-- Überschrift -->
#                            <h3>
#                               <a href="http://www.uni-mainz.de/studium/95_DEU_HTML.php">Studienplanung und -organisation</a>
#                            </h3><!-- Teasertext und Link mehr -->
#                            <p>
#                               Sie sind Erstsemester und möchten Ihren Stundenplan zusammenstellen? Sie studieren bereits an der JGU und möchten ein Fach wechseln? Sie stehen kurz vor dem Abschluss und möchten Zusatzqualifikationen erwerben? Wir haben die Antworten auf Ihre Fragen!
#                               <br/>
#                               <a class="detaillink" href="http://www.uni-mainz.de/studium/95_DEU_HTML.php">mehr</a>
#                            </p>
#                         </div>
#                         <div class="row teaser">
#                            <p></p><!-- Bilddarstellung -->
#                            <a class="bildlink" href="http://www.career.uni-mainz.de/index.php"><img alt="Kleines Bild" class="left" src="/Illustrationen/studium_career_service_150x100.jpg" title="Kleines Bild"/></a> <!-- Überschrift -->
#                            <h3>
#                               <a href="http://www.career.uni-mainz.de/index.php">Berufsorientierung</a>
#                            </h3><!-- Teasertext und Link mehr -->
#                            <p>
#                               Das Portal Career Service gibt Ihnen einen Überblick über die Informations-, Beratungs- und Veranstaltungsangebote verschiedener Einrichtungen an der JGU, die Sie – je nach individueller Situation – bei der Planung Ihrer beruflichen Zukunft unterstützen.
#                               <br/>
#                               <a class="detaillink" href="http://www.career.uni-mainz.de/index.php">mehr</a>
#                            </p>
#                         </div>
#                         <div class="row">
#                            <a class="listlink" href="http://www.career.uni-mainz.de/index.php">ZUM PORTAL CAREER SERVICE</a>
#                         </div>
#                      </div><!-- /.teaserlist -->
#                   </div>
#                   <div class="col-sm-4 col-md-4 col-xs-12" style="margin-left: 0.2em;">
#                      <div class="nav_targetaudience_header content teaserlist nav_targetaudience_colored">
#                         <div class="row">
#                            <h2>
#                               INFORMATION UND BERATUNG
#                            </h2>
#                         </div>
#                         <div class="row teaser">
#                            <p></p><!-- Bilddarstellung -->
#                            <a class="bildlink" href="http://www.uni-mainz.de/studium/400_DEU_HTML.php"><img alt="Kleines Bild" class="left" src="/Illustrationen/studium_online-bewerbung_02_150x100.jpg" title="Kleines Bild"/></a> <!-- Überschrift -->
#                            <h3>
#                               <a href="http://www.uni-mainz.de/studium/400_DEU_HTML.php">Sie suchen Ansprechpartner an der JGU?</a>
#                            </h3><!-- Teasertext und Link mehr -->
#                            <p>
#                               Mit einem Studium hängen viele Fragen zusammen. Nutzen Sie diese Angebote, werden Sie aktiv und suchen Sie die Ansprechpartner/innen auf, die Ihnen bei Ihrem Anliegen weiterhelfen können. Hier finden Sie alle relevanten Informationen.
#                               <br/>
#                               <a class="detaillink" href="http://www.uni-mainz.de/studium/400_DEU_HTML.php">mehr</a>
#                            </p>
#                         </div>
#                         <div class="row teaser">
#                            <p></p><!-- Bilddarstellung -->
#                            <a class="bildlink" href="http://www.info.jogustine.uni-mainz.de/"><img alt="Kleines Bild" class="left" src="/Illustrationen/meatjgu.gif" title="Kleines Bild"/></a> <!-- Überschrift -->
#                            <h3>
#                               <a href="http://www.info.jogustine.uni-mainz.de/">me@JGU</a>
#                            </h3><!-- Teasertext und Link mehr -->
#                            <p>
#                               Dein Portal für mehr Gelassenheit im Studium
#                               <br/>
#                               <a class="detaillink" href="http://www.info.jogustine.uni-mainz.de/">mehr</a>
#                            </p>
#                         </div>
#                         <div class="row">
#                            <a class="listlink" href="http://www.uni-mainz.de/studium/95_DEU_HTML.php">ZUM PORTAL STUDIUM</a>
#                         </div>
#                      </div><!-- /.teaserlist -->
#                   </div>
#                </div><!-- /#nav_targetaudience_content_home -->
#                <!-- Studierende -->
#                <div class="row row-flex row-flex-wrap colored nav_targetaudience_content" id="nav_targetaudience_content_3" style="display: none;">
#                   <!-- in class:  -->
#                   <!-- ausserhalb von class:  -->
#                   <div class="col-sm-4 col-md-4 col-xs-12" style="margin-right: 0.2em;">
#                      <div class="nav_targetaudience_header content teaserlist nav_targetaudience_colored">
#                         <div class="row">
#                            <h2>
#                               AKTUELLES
#                            </h2>
#                         </div>
#                         <div class="row teaser">
#                            <p></p><!-- Bilddarstellung -->
#                            <a class="bildlink" href="https://www.aventis-foundation.org/wissenschaft/life-sciences-bridge-award/"></a> <!-- Überschrift -->
#                            <h3>
#                               <a href="https://www.aventis-foundation.org/wissenschaft/life-sciences-bridge-award/">Ausschreibung der Aventis Foundation: Life Sciences Bridge Award 2022</a>
#                            </h3><!-- Teasertext und Link mehr -->
#                            <p>
#                               Der Postdoctoral Award der Aventis Foundation richtet sich an Nachwuchswissenschaftlerinnen und -wissenschaftler der Lebenswissenschaften. Der Preis ist mit individuell 100.000€ dotiert. Die Bewerbungsfrist läuft vom 01. März bis zum 30. April.
#                               <br/>
#                               <a class="detaillink" href="https://www.aventis-foundation.org/wissenschaft/life-sciences-bridge-award/">mehr</a>
#                            </p>
#                         </div>
#                         <div class="row teaser">
#                            <p></p><!-- Bilddarstellung -->
#                            <a class="bildlink" href="https://grk2516.uni-mainz.de/ukraine/"></a> <!-- Überschrift -->
#                            <h3>
#                               <a href="https://grk2516.uni-mainz.de/ukraine/">Besuchsstipendium für ukrainische Doktoranden</a>
#                            </h3><!-- Teasertext und Link mehr -->
#                            <p>
#                               Das Graduiertenkolleg GRK2516 bietet geförderte Stipendien für ukrainische Doktoranden an, die bereits eine Promotion auf dem Gebiet der (weichen) kondensierten Materie begonnen haben und ihr Land verlassen mussten.
#                               <br/>
#                               <a class="detaillink" href="https://grk2516.uni-mainz.de/ukraine/">mehr</a>
#                            </p>
#                         </div>
#                         <div class="row">
#                            <a class="listlink" href="http://www.nachwuchs.uni-mainz.de/">ZUM PORTAL FÜR DEN WISSENSCHAFTLICHEN UND KÜNSTLERISCHEN NACHWUCHS</a>
#                         </div>
#                      </div><!-- /.teaserlist -->
#                   </div>
#                   <div class="col-sm-4 col-md-4 col-xs-12" style="margin-left: 0.2em; margin-right: 0.2em;">
#                      <div class="nav_targetaudience_header content teaserlist nav_targetaudience_colored">
#                         <div class="row">
#                            <h2>
#                               VERANSTALTUNGEN
#                            </h2>
#                         </div>
#                         <div class="row teaser">
#                            <p></p><!-- Bilddarstellung -->
#                            <a class="bildlink" href="https://www.zq.uni-mainz.de/files/2021/12/F_A2-2_GSP-2022_Verse.pdf"></a> <!-- Überschrift -->
#                            <h3>
#                               <a href="https://www.zq.uni-mainz.de/files/2021/12/F_A2-2_GSP-2022_Verse.pdf">Veranstaltung des General Postgraduate Program: Good Scientific Practice Workshop am 23. März von 9:30 Uhr - 16:15 Uhr und 24. März von 9:30 Uhr - 16:15 Uh:00 Uhr</a>
#                            </h3><!-- Teasertext und Link mehr -->
#                            <p>
#                               Das Hauptziel dieses Kurses ist es, die grundlegenden Regeln und Werte der verantwortungsvollem Umgang mit der Forschung gemäß den lokalen, nationalen und internationalen Vorschriften und Richtlinien.
#                               <br/>
#                               <a class="detaillink" href="https://www.zq.uni-mainz.de/files/2021/12/F_A2-2_GSP-2022_Verse.pdf">mehr</a>
#                            </p>
#                         </div>
#                         <div class="row teaser">
#                            <p></p><!-- Bilddarstellung -->
#                            <a class="bildlink" href="https://www.uni-frankfurt.de/52403217/Aktuelle_GRADE_Career_Talks"></a> <!-- Überschrift -->
#                            <h3>
#                               <a href="https://www.uni-frankfurt.de/52403217/Aktuelle_GRADE_Career_Talks">Veranstaltung der RMU-Partneruniversität Frankfurt: "GRADE Online Karrieregespräch zum Thema: Early Career Researchers und Karrieren in der Wissenschaft " am 24. März um 17:00 Uhr</a>
#                            </h3><!-- Teasertext und Link mehr -->
#                            <p>
#                               Weniger als 10 Prozent aller Promovierten werden einmal Prof. Jedoch gibt es auch außerhalb von Professuren attraktive Karrieremöglichkeiten in der Wissenschaft. Prof. Dr. Brigitta Wolff im Gespräch über die Promotion als auch über Perspektiven danach.
#                               <br/>
#                               <a class="detaillink" href="https://www.uni-frankfurt.de/52403217/Aktuelle_GRADE_Career_Talks">mehr</a>
#                            </p>
#                         </div>
#                         <div class="row">
#                            <a class="listlink" href="http://www.nachwuchs.uni-mainz.de/">ZUM PORTAL FÜR DEN WISSENSCHAFTLICHEN UND KÜNSTLERISCHEN NACHWUCHS</a>
#                         </div>
#                      </div><!-- /.teaserlist -->
#                   </div>
#                   <div class="col-sm-4 col-md-4 col-xs-12" style="margin-left: 0.2em;">
#                      <div class="nav_targetaudience_header content teaserlist nav_targetaudience_colored">
#                         <div class="row">
#                            <h2>
#                               Qualifizierung
#                            </h2>
#                         </div>
#                         <div class="row teaser">
#                            <p></p><!-- Bilddarstellung -->
#                            <a class="bildlink" href="https://www.zq.uni-mainz.de/wissenschaftlicher-nachwuchs/apk/"></a> <!-- Überschrift -->
#                            <h3>
#                               <a href="https://www.zq.uni-mainz.de/wissenschaftlicher-nachwuchs/apk/">Das Allgemeine Promotionskolleg</a>
#                            </h3><!-- Teasertext und Link mehr -->
#                            <p>
#                               Von Schreibwerkstatt bis zur Karriereplanung: Das Allgemeine Promotionskolleg (APK) der JGU bietet Doktorandinnen und Doktoranden der JGU ein abwechslungsreiches Programm. Aktuell sind noch Plätze in einigen Kursen verfügbar.
#                               <br/>
#                               <a class="detaillink" href="https://www.zq.uni-mainz.de/wissenschaftlicher-nachwuchs/apk/">mehr</a>
#                            </p>
#                         </div>
#                         <div class="row teaser">
#                            <p></p><!-- Bilddarstellung -->
#                            <a class="bildlink" href="https://gleichstellung.uni-mainz.de/programm-weiblicher-wissenschaftsnachwuchs-prowewin/"></a> <!-- Überschrift -->
#                            <h3>
#                               <a href="https://gleichstellung.uni-mainz.de/programm-weiblicher-wissenschaftsnachwuchs-prowewin/">Programm Weiblicher Wissenschaftsnachwuchs (ProWeWin)</a>
#                            </h3><!-- Teasertext und Link mehr -->
#                            <p>
#                               Das Programm Weiblicher Wissenschaftsnachwuchs (ProWeWin) hält für Nachwuchswissenschaftlerinnen in der späten Promotionsphase und PostDocs Workshopangebote zur Erlangung von wissenschaftsrelevanten Schlüsselqualifikationen vor.
#                               <br/>
#                               <a class="detaillink" href="https://gleichstellung.uni-mainz.de/programm-weiblicher-wissenschaftsnachwuchs-prowewin/">mehr</a>
#                            </p>
#                         </div>
#                         <div class="row">
#                            <a class="listlink" href="http://www.gnk.uni-mainz.de/">ZUM GUTENBERG NACHWUCHSKOLLEG</a>
#                         </div>
#                      </div><!-- /.teaserlist -->
#                   </div>
#                </div><!-- /#nav_targetaudience_content_home -->
#                <!-- Wiss. Nachwuchs -->
#                <div class="row row-flex row-flex-wrap colored nav_targetaudience_content" id="nav_targetaudience_content_4" style="display: none;">
#                   <!-- in class:  -->
#                   <!-- ausserhalb von class:  -->
#                   <div class="col-sm-4 col-md-4 col-xs-12" style="margin-right: 0.2em;">
#                      <div class="nav_targetaudience_header content teaserlist nav_targetaudience_colored">
#                         <div class="row">
#                            <h2>
#                               FORSCHUNGSFÖRDERUNG
#                            </h2>
#                         </div>
# ...
#                               <br/>
#                               <a class="detaillink" href="https://download.uni-mainz.de/presse/P_statement_ukraine.pdf">mehr</a>
#                            </p>
#                         </div>
#                         <div class="row teaser">
#                            <p></p><!-- Bilddarstellung -->
#                            <a class="bildlink" href="https://www.uni-mainz.de/presse/aktuell/15209_DEU_HTML.php"><img alt="Kleines Bild" class="left" src="/Illustrationen/09_geografie_buche_baumringe_150x100.jpg" title="Kleines Bild"/></a> <!-- Überschrift -->
#                            <h3>
#                               <a href="https://www.uni-mainz.de/presse/aktuell/15209_DEU_HTML.php">Europas Buchenwäldern droht erhebliche Gefahr durch Klimawandel</a>
#                            </h3><!-- Teasertext und Link mehr -->
#                            <p>
#                               Baumringanalysen zeigen Wachstumseinbußen in den vergangenen Jahrzehnten / Weitere, teils drastische Rückgänge vor allem in Südeuropa zu erwarten
#                               <br/>
#                               <a class="detaillink" href="https://www.uni-mainz.de/presse/aktuell/15209_DEU_HTML.php">mehr</a>
#                            </p>
#                         </div>
#                         <div class="row">
#                            <a class="listlink" href="https://www.uni-mainz.de/presse/aktuell/32_DEU_HTML.php">ZU DEN PRESSEMITTEILUNGEN</a>
#                         </div>
#                      </div><!-- /.teaserlist -->
#                   </div>
#                   <div class="col-sm-4 col-md-4 col-xs-12" style="margin-left: 0.2em; margin-right: 0.2em;">
#                      <div class="nav_targetaudience_header content teaserlist nav_targetaudience_colored">
#                         <div class="row">
#                            <h2>
#                               AKTUELLES
#                            </h2>
#                         </div>
#                         <div class="row teaser">
#                            <p></p><!-- Bilddarstellung -->
#                            <a class="bildlink" href="https://www.uni-mainz.de/presse/aktuell/15168_DEU_HTML.php"><img alt="Kleines Bild" class="left" src="/Illustrationen/logo_ZWW_150x100.jpg" title="Kleines Bild"/></a> <!-- Überschrift -->
#                            <h3>
#                               <a href="https://www.uni-mainz.de/presse/aktuell/15168_DEU_HTML.php">ZWW koordiniert EU-Projekt für intergenerationelles Lernen durch gesellschaftliches Engagement</a>
#                            </h3><!-- Teasertext und Link mehr -->
#                            <p>
#                               Sechs Partnerländer "Intergenerational Digital Service Learning" beteiligt
#                               <br/>
#                               <a class="detaillink" href="https://www.uni-mainz.de/presse/aktuell/15168_DEU_HTML.php">mehr</a>
#                            </p>
#                         </div>
#                         <div class="row teaser">
#                            <p></p><!-- Bilddarstellung -->
#                            <a class="bildlink" href="https://www.uni-mainz.de/presse/aktuell/15135_DEU_HTML.php"><img alt="Kleines Bild" class="left" src="/Illustrationen/MWG_foerderbescheid_hochschulbibliotheken_digitalisierung_150x100.jpg" title="Kleines Bild"/></a> <!-- Überschrift -->
#                            <h3>
#                               <a href="https://www.uni-mainz.de/presse/aktuell/15135_DEU_HTML.php">Digitalisierung der Hochschulbibliotheken: Wissenschaftsminister Clemens Hoch überreicht Landesförderung in Höhe von über einer Million Euro an drei rheinland-pfälzische Hochschulen</a>
#                            </h3><!-- Teasertext und Link mehr -->
#                            <p>
#                               JGU erhält zusätzliche Mittel zur Etablierung eines virtuellen Leitsystems für ihre Bibliotheksstandorte
#                               <br/>
#                               <a class="detaillink" href="https://www.uni-mainz.de/presse/aktuell/15135_DEU_HTML.php">mehr</a>
#                            </p>
#                         </div>
#                         <div class="row">
#                            <a class="listlink" href="https://www.uni-mainz.de/pressemitteilungen">ZU DEN PRESSEMITTEILUNGEN</a>
#                         </div>
#                      </div><!-- /.teaserlist -->
#                   </div>
#                   <div class="col-sm-4 col-md-4 col-xs-12" style="margin-left: 0.2em;">
#                      <div class="nav_targetaudience_header content teaserlist nav_targetaudience_colored">
#                         <div class="row">
#                            <h2>
#                               AKTUELLES
#                            </h2>
#                         </div>
#                         <div class="row teaser">
#                            <p></p><!-- Bilddarstellung -->
#                            <a class="bildlink" href="https://www.uni-mainz.de/presse/aktuell/15142_DEU_HTML.php"><img alt="Kleines Bild" class="left" src="/Illustrationen/GFK_gutenberg_research_award_2021_roebroeks_150x100.jpg" title="Kleines Bild"/></a> <!-- Überschrift -->
#                            <h3>
#                               <a href="https://www.uni-mainz.de/presse/aktuell/15142_DEU_HTML.php">Gutenberg Research Award für Wil Roebroeks</a>
#                            </h3><!-- Teasertext und Link mehr -->
#                            <p>
#                               JGU vergibt ihren bedeutendsten Forschungspreis an niederländischen Archäologen
#                               <br/>
#                               <a class="detaillink" href="https://www.uni-mainz.de/presse/aktuell/15142_DEU_HTML.php">mehr</a>
#                            </p>
#                         </div>
#                         <div class="row teaser">
#                            <p></p><!-- Bilddarstellung -->
#                            <a class="bildlink" href="https://corona.uni-mainz.de/"><img alt="Kleines Bild" class="left" src="/Illustrationen/logo_JGU_kasten_150x100.jpg" title="Kleines Bild"/></a> <!-- Überschrift -->
#                            <h3>
#                               <a href="https://corona.uni-mainz.de/">Allgemeine Information zum Umgang der JGU mit der Corona-Pandemie</a>
#                            </h3><!-- Teasertext und Link mehr -->
#                            <p>
#                               Die JGU ist seit dem 7. Juni 2021 wieder im eingeschränkten Regelbetrieb.
#                               <br/>
#                               <a class="detaillink" href="https://corona.uni-mainz.de/">mehr</a>
#                            </p>
#                         </div>
#                         <div class="row">
#                            <a class="listlink" href="https://www.uni-mainz.de/presse/">IHRE ANSPRECHPARTNER IN DER STABSSTELLE KOMMUNIKATION UND PRESSE</a>
#                         </div>
#                      </div><!-- /.teaserlist -->
#                   </div>
#                </div><!-- /#nav_targetaudience_content_home -->
#                <!-- Presse -->
#                <!-- /32.php -->
#                <div class="row" id="jgu_magazin">
#                   <div class="magazine">
#                      <div class="content">
#                         <h2>
#                            Magazin
#                         </h2><a class="bildlink" href="https://www.magazin.uni-mainz.de/12391_DEU_HTML.php" target="_blank" title="mehr lesen"><img alt="POLITISCHE ETHNOLOGIE" class="left" src="/Illustrationen/07_IFEAS_fay_franziska_250x150.jpg"/></a>
#                         <h3>
#                            POLITISCHE ETHNOLOGIE
#                         </h3>
#                         <h4>
#                            <a class="more" href="https://www.magazin.uni-mainz.de/12391_DEU_HTML.php" style="color: #c1002a;" target="_blank" title="mehr lesen">Disziplinierte Empathie als wichtiges Werkzeug in hochpolitischen Zeiten</a>
#                         </h4>
#                         <h5>
#                            10.03.2022
#                         </h5>
#                         <div class="editorcontent">
#                            <p>
#                               Über ein Jahrzehnt hinweg forschte Franziska Fay auf dem Sansibar-Archipel. Dort arbeitete sie mit Kinderschutzakteuren, Kindern in Grund- und Koranschulen, war Gastdozentin an der Universität und beriet internationale Hilfsorganisationen. Nach Stationen in Frankfurt und London ist sie seit vorigem Jahr Juniorprofessorin für politische Ethnologie am Institut für Ethnologie und Afrikastudien der Johannes Gutenberg-Universität Mainz (JGU) ...
#                            </p>
#                         </div>
#                      </div>
#                   </div><!-- /.magazine -->
#                   <div class="text-right" id="jgu_magazin_link">
#                      <a class="magazinlink" href="https://www.magazin.uni-mainz.de/12391_DEU_HTML.php" target="_blank" title="mehr lesen">ZUM JGU MAGAZIN</a>
#                   </div>
#                </div>               <div class="magazine row" id="jgu_offene_universitaet">
#                   <h2>
#                      Kooperationen und Partner
#                   </h2><noscript>Bitte beachten: zur Nutzung dieser Website empfehlen wir die Aktivierung von Javascript in Ihrem Browser.</noscript>
#                   <div class="carousel slide jgu_offene_universitaet_carousel" data-interval="10000" data-ride="carousel" id="jgu_offene_universitaet_carousel_id_4947">
#                      <div class="carousel-inner jgu_offene_uni_border" role="listbox">
#                         <div class="item slide active">
#                            <div class="col-md-2 col-sm-4 col-xs-6 text-center jgu_offene_uni_border_right">
#                               <a href="https://forschungsprofil.uni-mainz.de/weitere-verbundprojekte/"><img alt="" class="img_hover_opacity img_hover_size" src="/Illustrationen/logo_EU-emblem_250pxbreit.jpg" title=""/></a>
#                            </div>
#                            <div class="col-md-2 col-sm-4 col-xs-6 text-center jgu_offene_uni_border_right">
#                               <a href="https://www.forthem-alliance.eu/"><img alt=" - Externer Link" class="img_hover_opacity img_hover_size" src="/Illustrationen/logo_forthem_250pxbreit.jpg" title=" - Externer Link"/></a>
#                            </div>
#                            <div class="col-md-2 col-sm-4 col-xs-6 text-center jgu_offene_uni_border_right">
#                               <a href="https://www.german-u15.de/"><img alt=" - Externer Link" class="img_hover_opacity img_hover_size" src="/Illustrationen/logo_german_u15_150x100.jpg" title=" - Externer Link"/></a>
#                            </div>
#                            <div class="col-md-2 col-sm-4 col-xs-6 text-center jgu_offene_uni_border_right">
#                               <a href="https://www.rhein-main-universitaeten.de/"><img alt=" - Externer Link" class="img_hover_opacity img_hover_size" src="/Illustrationen/logo_RMU_250pxbreit_02.jpg" title=" - Externer Link"/></a>
#                            </div>
#                            <div class="col-md-2 col-sm-4 col-xs-6 text-center jgu_offene_uni_border_right">
#                               <a href="https://www.wissenschaftsallianz-mainz.de/"><img alt=" - Externer Link" class="img_hover_opacity img_hover_size" src="/Illustrationen/logo_mainzer_wissenschaftsallianz_250x150.jpg" title=" - Externer Link"/></a>
#                            </div>
#                            <div class="col-md-2 col-sm-4 col-xs-6 text-center">
#                               <a href="https://www.hrk.de/weltoffene-hochschulen"><img alt=" - Externer Link" class="img_hover_opacity img_hover_size" src="/Illustrationen/logo_weltoffene_hochschulen_150x100.jpg" title=" - Externer Link"/></a>
#                            </div>
#                         </div>                     </div>
#                      <div class="carousel-controls row" style="border-color:#ebebeb;">
#                         <div class="col-sm-2 col-md-2 col-xs-2 text-left carousel-control-left"></div>
#                         <div class="col-sm-8 col-md-8 col-xs-8">
#                            <!-- Positionsanzeige -->
#                            <ol class="carousel-indicators">
#                               <li class="active" data-slide-to="0" data-target="#jgu_offene_universitaet_carousel_id_4947">
#                                  <dfn class="sr-only">Zu Ansicht 0</dfn>
#                               </li>
#                            </ol>
#                         </div>
#                         <div class="col-sm-2 col-md-2 col-xs-2 text-right carousel-control-right"></div>
#                      </div>
#                   </div>
#                </div><!-- Hier kommen Imagescroller und ZGN, sowie... -->
#                <!-- Hier wird der Inhalt des Textfeldes der Seite als 'Magazin' sichtbar gemacht. Ein/Ausblenden mit JS muss noch passieren -->
#                <!-- Offene Universität Scroller --><div class="row"><!-- Spaltenlayout gemäß Einstellungen für option_schalter_linke_spalte, option_schalter_rechte_spalte --><!-- Mittlere Spalte -->
#                <article class="col-sm-12 col-md-12" id="spaltemitte">
#                   <!-- Beginn Inhalt Spalte Mitte -->
#                   <!-- Ende Inhalt Spalte Mitte -->
#                </article><!-- Rechte Spalte -->
#                </div><!-- .row -->            </div>
#          </main><!-- # content -->
#          <footer class="container" id="main-footer">
#             <div class="col-sm-4" id="footer_pageinfos">
#                <span class="sr-only">Zusatzinformationen zu dieser Seite</span>
#                <ul class="list-inline">
#                   <li>
#                      <dfn class="sr-only">Name der Seite:</dfn> Johannes Gutenberg-Universität Mainz
#                   </li>
#                   <li>
#                      10.03.2022                  </li>
#                </ul>
#             </div>
#             <div class="col-sm-4" id="footer_social">
#                <ul>
#                   <li class="icon_facebook">
#                      <a href="http://www.facebook.com/unimainz" title="Externer Link"><dfn class="sr-only">Facebook</dfn></a>
#                   </li>
#                   <li class="icon_twitter">
#                      <a href="http://twitter.com/uni_mainz" title="Externer Link"><dfn class="sr-only">Twitter</dfn></a>
#                   </li>
#                   <li class="icon_rss">
#                      <a href="/32.php"><dfn class="sr-only">RSS</dfn></a>
#                   </li>
#                   <li class="icon_youtube">
#                      <a href="http://www.youtube.com/universitaetmainz" title="Externer Link"><dfn class="sr-only">Youtube</dfn></a>
#                   </li>
#                </ul>
#             </div>
#             <div class="col-sm-4" id="footer_servicenav">
#                <ul class="list-inline">
#                   <li>
#                      <script type="text/javascript">
#                      rd_ml('webmaster', 'uni-mainz', 'de', 'Webmaster')
#                      </script><noscript>(Maillink: webmaster (AT) uni-mainz (PUNKT) de)</noscript>
#                   </li>
#                   <li>
#                      <a href="/144.php" title="Privacy">Datenschutz</a>
#                   </li>
#                   <li>
#                      <a accesskey="6" href="http://www.uni-mainz.de/impressum" title="Impressum">Impressum</a>
#                   </li>
#                   <li>
#                      <a href="https://www.uni-mainz.de/barrierefreiheit" title="Barrierefreiheit">Barrierefreiheit</a>
#                   </li>
#                   <li>
#                      <a href="#page_start">Zum Seitenanfang</a>
#                   </li>
#                </ul>
#             </div>
#          </footer>
#       </div><!-- container -->
#       <script src="//css.uni-mainz.de/js/jgu.min.js?v="></script>
#
# </body></html>

# %%
soup('meta')
# Out:
# [<meta charset="utf-8"/>,
#  <meta content="IE=edge" http-equiv="X-UA-Compatible"/>,
#  <meta content="width=device-width, initial-scale=1.0" name="viewport"/>,
#  <meta content="Johannes Gutenberg-Universität Mainz" name="author"/>,
#  <meta content="Die Johannes Gutenberg-Universität Mainz zählt mit rund 33.000 Studierenden aus über 130 Nationen zu den zehn größten Universitäten Deutschlands. Als einzige Volluniversität in Rheinland-Pfalz vereint sie nahezu alle akademischen Disziplinen." name="description"/>,
#  <meta content="2" name="page_id"/>,
#  <meta content="Johannes Gutenberg-Universität Mainz" name="copyright"/>,
#  <meta content="" name="Linktitle"/>,
#  <meta content="" name="keywords"/>,
#  <meta content="index, follow, noarchive" name="robots"/>,
#  <meta content="" name="generator"/>]

# %%
for element in soup('meta'):
    if 'content' in element.attrs:
        print(element['content'])
# Out:
# IE=edge
# width=device-width, initial-scale=1.0
# Johannes Gutenberg-Universität Mainz
# Die Johannes Gutenberg-Universität Mainz zählt mit rund 33.000 Studierenden aus über 130 Nationen zu den zehn größten Universitäten Deutschlands. Als einzige Volluniversität in Rheinland-Pfalz vereint sie nahezu alle akademischen Disziplinen.
# 2
# Johannes Gutenberg-Universität Mainz
#
#
# index, follow, noarchive

# %% [markdown]
# ## Repräsentation von HTML durch BS4
#
# * *Tag* $\rightarrow$ Attribute eines Python-Objekts.
# * *Attribute* $\rightarrow$ Python `dict` mit dem Namen des Attributs als Schlüssel.
# * *Text* $\rightarrow$ als Attribut `.text`.

# %%
soup.ul.a
# Out:
# <a accesskey="1" href="/index.php" target="_top" title="Startseite dieser Website">Home</a>

# %% [markdown]
# # Den Baum durchsuchen

# %% [markdown]
# ## `.find()` und`.find_all()`
#
# Diese Methoden wenden [Filter](https://www.crummy.com/software/BeautifulSoup/bs4/doc/#kinds-of-filters) auf den Baum-Graphen oder Teile davon an um bestimmte Teile des Baums als Ausgabe zu erhalten. Folgende Objekte können als Filter verwendet werden:
#
# * Strings
# * Reguläre Ausdrücke
# * Listen (Elemente mit logischem ODER verknüpft)
# * `True`
# * Funktionen

# %% [markdown]
# ## Keyword Arguments
#
# Per Standard werden Keyword (benannte Argumente) als Filter für entsprechende bennante HTML-Attribute verwendet. Der Filter gibt dann Elemente zurück bei denen das entsprechende Attribut den spezifizierten Wert aufweist.
#
# Hinweis: Das HTML-Attribut `class` kann nur über das keyword `class_` angesprochen werden!

# %%
## Beispiel alle Tags finden

set([tag.name for tag in soup.find_all(True)])
# Out:
# {'a',
#  'article',
#  'body',
#  'br',
#  'button',
#  'dfn',
#  'div',
#  'fieldset',
#  'footer',
#  'form',
#  'h2',
#  'h3',
#  'h4',
#  'h5',
#  'head',
#  'header',
#  'html',
#  'img',
#  'input',
#  'label',
#  'legend',
#  'li',
#  'link',
#  'main',
#  'meta',
#  'nav',
#  'nobr',
#  'noscript',
#  'ol',
#  'p',
#  'script',
#  'span',
#  'strong',
#  'title',
#  'ul'}

# %%
## Übung: Alle Hyperlinks finden

[element['href'] for element in soup.find_all(href=True)]
# Out:
# ['/Illustrationen/favicon.ico',
#  '/Illustrationen/favicon.ico',
#  'http://www.uni-mainz.de/index.php',
#  '//css.uni-mainz.de/css/jgu_style.min.css?v=1571842591',
#  '/32.php',
#  '//www.uni-mainz.de',
#  '//www.uni-mainz.de',
#  '//www.uni-mainz.de',
#  '/index.php',
#  '//www.uni-mainz.de',
#  '//www.uni-mainz.de',
#  '//www.uni-mainz.de',
#  '#',
#  '/index.php',
#  'http://www.uni-mainz.de/suche',
#  'http://www.uni-mainz.de/kontakt',
#  '/eng/index.php',
#  'https://universitaet.uni-mainz.de',
#  'https://organisation.uni-mainz.de',
#  'https://fachbereiche.uni-mainz.de/',
#  'https://www.studium.uni-mainz.de/',
#  'https://lehre.uni-mainz.de',
#  'https://forschungsprofil.uni-mainz.de',
#  'https://wissenschaftliche-weiterbildung.uni-mainz.de',
#  '/index.php',
#  'http://www.uni-mainz.de/suche',
#  'http://www.uni-mainz.de/kontakt',
#  '/eng/index.php',
#  '#menu2',
#  'https://universitaet.uni-mainz.de',
#  'https://organisation.uni-mainz.de',
#  'https://fachbereiche.uni-mainz.de/',
#  'https://www.studium.uni-mainz.de/',
#  'https://lehre.uni-mainz.de',
#  'https://forschungsprofil.uni-mainz.de',
#  'https://wissenschaftliche-weiterbildung.uni-mainz.de',
#  'https://www.studium.uni-mainz.de/einfuehrungsveranstaltungen/',
#  'https://www.studium.uni-mainz.de/einfuehrungsveranstaltungen/',
#  'https://www.uni-mainz.de/presse/aktuell/13679_DEU_HTML.php',
#  'https://www.uni-mainz.de/presse/aktuell/13679_DEU_HTML.php',
#  'https://www.studium.uni-mainz.de/studienwahl-podcast/',
#  'https://www.studium.uni-mainz.de/studienwahl-podcast/',
#  'https://gutenberg-netzwerk.uni-mainz.de/projekte/75aus75',
#  'https://gutenberg-netzwerk.uni-mainz.de/projekte/75aus75',
#  '#jgu_carousel_id_50',
#  '#jgu_carousel_id_50',
#  'https://jogustine.uni-mainz.de/',
#  'https://personen.uni-mainz.de/',
#  'http://www.studium.uni-mainz.de/',
#  'http://www.international.uni-mainz.de',
#  'https://karriere.uni-mainz.de/',
#  '/index.php',
#  '/index.php',
#  '/index.php',
#  '/index.php',
#  '/index.php',
#  '/index.php',
#  '/index.php',
#  '/index.php',
#  '/index.php',
#  'https://www.studium.uni-mainz.de/hochschulmessen/',
#  'https://www.studium.uni-mainz.de/hochschulmessen/',
#  'https://www.studium.uni-mainz.de/hochschulmessen/',
#  'https://www.studium.uni-mainz.de/studienorientierung/',
#  'https://www.studium.uni-mainz.de/studienorientierung/',
#  'https://www.studium.uni-mainz.de/studienorientierung/',
#  'http://www.studium.uni-mainz.de',
#  'http://www.uni-mainz.de/studium/99_DEU_HTML.php',
#  'http://www.uni-mainz.de/studium/99_DEU_HTML.php',
#  'http://www.uni-mainz.de/studium/99_DEU_HTML.php',
#  'http://www.uni-mainz.de/studium/473_DEU_HTML.php',
#  'http://www.uni-mainz.de/studium/473_DEU_HTML.php',
#  'http://www.uni-mainz.de/studium/473_DEU_HTML.php',
#  'http://www.uni-mainz.de/studium/index.php',
#  'http://www.uni-mainz.de/studium/index.php',
#  'http://www.uni-mainz.de/studium/index.php',
#  'http://www.uni-mainz.de/studium/index.php',
#  'http://www.uni-mainz.de/studium/400_DEU_HTML.php',
#  'http://www.uni-mainz.de/studium/400_DEU_HTML.php',
#  'http://www.uni-mainz.de/studium/400_DEU_HTML.php',
#  'http://www.uni-mainz.de/studium/index.php',
#  'https://sl.uni-mainz.de/information-zum-umgang-der-jgu-mit-dem-coronavirus/',
#  'https://sl.uni-mainz.de/information-zum-umgang-der-jgu-mit-dem-coronavirus/',
#  'https://sl.uni-mainz.de/information-zum-umgang-der-jgu-mit-dem-coronavirus/',
#  'https://www.studium.uni-mainz.de',
#  'https://www.studium.uni-mainz.de',
#  'https://www.studium.uni-mainz.de',
#  'http://www.uni-mainz.de/studium/95_DEU_HTML.php',
#  'http://www.uni-mainz.de/studium/95_DEU_HTML.php',
#  'http://www.uni-mainz.de/studium/95_DEU_HTML.php',
#  'http://www.uni-mainz.de/studium/95_DEU_HTML.php',
#  'http://www.career.uni-mainz.de/index.php',
#  'http://www.career.uni-mainz.de/index.php',
#  'http://www.career.uni-mainz.de/index.php',
#  'http://www.career.uni-mainz.de/index.php',
#  'http://www.uni-mainz.de/studium/400_DEU_HTML.php',
#  'http://www.uni-mainz.de/studium/400_DEU_HTML.php',
#  'http://www.uni-mainz.de/studium/400_DEU_HTML.php',
#  'http://www.info.jogustine.uni-mainz.de/',
#  'http://www.info.jogustine.uni-mainz.de/',
#  'http://www.info.jogustine.uni-mainz.de/',
#  'http://www.uni-mainz.de/studium/95_DEU_HTML.php',
#  'https://www.aventis-foundation.org/wissenschaft/life-sciences-bridge-award/',
#  'https://www.aventis-foundation.org/wissenschaft/life-sciences-bridge-award/',
#  'https://www.aventis-foundation.org/wissenschaft/life-sciences-bridge-award/',
#  'https://grk2516.uni-mainz.de/ukraine/',
#  'https://grk2516.uni-mainz.de/ukraine/',
#  'https://grk2516.uni-mainz.de/ukraine/',
#  'http://www.nachwuchs.uni-mainz.de/',
#  'https://www.zq.uni-mainz.de/files/2021/12/F_A2-2_GSP-2022_Verse.pdf',
#  'https://www.zq.uni-mainz.de/files/2021/12/F_A2-2_GSP-2022_Verse.pdf',
#  'https://www.zq.uni-mainz.de/files/2021/12/F_A2-2_GSP-2022_Verse.pdf',
#  'https://www.uni-frankfurt.de/52403217/Aktuelle_GRADE_Career_Talks',
#  'https://www.uni-frankfurt.de/52403217/Aktuelle_GRADE_Career_Talks',
#  'https://www.uni-frankfurt.de/52403217/Aktuelle_GRADE_Career_Talks',
#  'http://www.nachwuchs.uni-mainz.de/',
#  'https://www.zq.uni-mainz.de/wissenschaftlicher-nachwuchs/apk/',
#  'https://www.zq.uni-mainz.de/wissenschaftlicher-nachwuchs/apk/',
#  'https://www.zq.uni-mainz.de/wissenschaftlicher-nachwuchs/apk/',
#  'https://gleichstellung.uni-mainz.de/programm-weiblicher-wissenschaftsnachwuchs-prowewin/',
#  'https://gleichstellung.uni-mainz.de/programm-weiblicher-wissenschaftsnachwuchs-prowewin/',
#  'https://gleichstellung.uni-mainz.de/programm-weiblicher-wissenschaftsnachwuchs-prowewin/',
#  'http://www.gnk.uni-mainz.de/',
#  'https://forschung.uni-mainz.de/kontakt/',
#  'https://forschung.uni-mainz.de/kontakt/',
#  'https://forschung.uni-mainz.de/kontakt/',
#  'https://www.forschungsdaten.uni-mainz.de/',
#  'https://www.forschungsdaten.uni-mainz.de/',
#  'https://www.forschungsdaten.uni-mainz.de/',
#  'https://forschung.uni-mainz.de/',
#  'https://www.nachwuchs.uni-mainz.de/',
#  'https://www.nachwuchs.uni-mainz.de/',
#  'https://www.nachwuchs.uni-mainz.de/',
#  'https://forschung.uni-mainz.de/kontakt/inneruniversitaere-forschungsfoerderung/',
#  'https://forschung.uni-mainz.de/kontakt/inneruniversitaere-forschungsfoerderung/',
#  'https://forschung.uni-mainz.de/kontakt/inneruniversitaere-forschungsfoerderung/',
#  'https://forschung.uni-mainz.de/',
#  'https://forschung.uni-mainz.de/transfer/',
#  'https://forschung.uni-mainz.de/transfer/',
#  'https://forschung.uni-mainz.de/transfer/',
#  'https://forschung.uni-mainz.de/startup-center/',
#  'https://forschung.uni-mainz.de/startup-center/',
#  'https://forschung.uni-mainz.de/startup-center/',
#  'https://forschung.uni-mainz.de/',
#  'https://www.personalentwicklung.uni-mainz.de/programm-2',
#  'https://www.personalentwicklung.uni-mainz.de/programm-2',
#  'https://www.personalentwicklung.uni-mainz.de/programm-2',
#  'https://www.personalentwicklung.uni-mainz.de/veraenderungsprozesse/jgu-leadership/',
#  'https://www.personalentwicklung.uni-mainz.de/veraenderungsprozesse/jgu-leadership/',
#  'https://www.personalentwicklung.uni-mainz.de/veraenderungsprozesse/jgu-leadership/',
#  'http://www.verwaltung.uni-mainz.de',
#  'http://www.uni-mainz.de/organisation/27_DEU_HTML.php',
#  'http://www.uni-mainz.de/organisation/27_DEU_HTML.php',
#  'http://www.uni-mainz.de/organisation/27_DEU_HTML.php',
#  'http://www.familienservice.uni-mainz.de/',
#  'http://www.familienservice.uni-mainz.de/',
#  'http://www.familienservice.uni-mainz.de/',
#  'http://www.verwaltung.uni-mainz.de',
#  'http://www.studium.uni-mainz.de/fristen-und-termine/',
#  'http://www.studium.uni-mainz.de/fristen-und-termine/',
#  'http://www.studium.uni-mainz.de/fristen-und-termine/',
#  'http://www.uni-mainz.de/downloads/JGU_leitlinien_guter_arbeit.pdf',
#  'http://www.uni-mainz.de/downloads/JGU_leitlinien_guter_arbeit.pdf',
#  'http://www.uni-mainz.de/downloads/JGU_leitlinien_guter_arbeit.pdf',
#  'http://www.verwaltung.uni-mainz.de',
#  'http://www.alumni.uni-mainz.de/index.php',
#  'http://www.alumni.uni-mainz.de/index.php',
#  'http://www.alumni.uni-mainz.de/index.php',
#  'https://gutenberg-netzwerk.uni-mainz.de/registrierung/',
#  'https://gutenberg-netzwerk.uni-mainz.de/registrierung/',
#  'https://gutenberg-netzwerk.uni-mainz.de/registrierung/',
#  'https://gutenberg-netzwerk.uni-mainz.de/',
#  'https://gutenberg-netzwerk.uni-mainz.de/angebote/alumnicard/',
#  'https://gutenberg-netzwerk.uni-mainz.de/angebote/alumnicard/',
#  'https://gutenberg-netzwerk.uni-mainz.de/angebote/alumnicard/',
#  'https://gutenberg-netzwerk.uni-mainz.de/alumniback/',
#  'https://gutenberg-netzwerk.uni-mainz.de/alumniback/',
#  'https://gutenberg-netzwerk.uni-mainz.de/alumniback/',
#  'https://gutenberg-netzwerk.uni-mainz.de/',
#  'https://gutenberg-netzwerk.uni-mainz.de/netzwerk/initiativen/',
#  'https://gutenberg-netzwerk.uni-mainz.de/netzwerk/initiativen/',
#  'https://gutenberg-netzwerk.uni-mainz.de/netzwerk/initiativen/',
#  'https://gutenberg-netzwerk.uni-mainz.de/gruppen/alumnibeauftragte/',
#  'https://gutenberg-netzwerk.uni-mainz.de/gruppen/alumnibeauftragte/',
#  'https://gutenberg-netzwerk.uni-mainz.de/gruppen/alumnibeauftragte/',
#  'https://gutenberg-netzwerk.uni-mainz.de/',
#  'http://www.foerdern-und-stiften.uni-mainz.de/1776.php',
#  'http://www.foerdern-und-stiften.uni-mainz.de/1776.php',
#  'http://www.foerdern-und-stiften.uni-mainz.de/1776.php',
#  'http://www.foerdern-und-stiften.uni-mainz.de/717.php',
#  'http://www.foerdern-und-stiften.uni-mainz.de/717.php',
#  'http://www.foerdern-und-stiften.uni-mainz.de/717.php',
#  'http://www.foerdern-und-stiften.uni-mainz.de/',
#  'http://www.foerdern-und-stiften.uni-mainz.de/966.php',
#  'http://www.foerdern-und-stiften.uni-mainz.de/966.php',
#  'http://www.foerdern-und-stiften.uni-mainz.de/966.php',
#  'https://www.uni-mainz.de/presse/aktuell/12182_DEU_HTML.php',
#  'https://www.uni-mainz.de/presse/aktuell/12182_DEU_HTML.php',
#  'https://www.uni-mainz.de/presse/aktuell/12182_DEU_HTML.php',
#  'http://www.foerdern-und-stiften.uni-mainz.de/',
#  'https://www.foerdern-und-stiften.uni-mainz.de/files/2021/09/foerdern-und-stiften_2021_1_web.pdf',
#  'https://www.foerdern-und-stiften.uni-mainz.de/files/2021/09/foerdern-und-stiften_2021_1_web.pdf',
#  'https://www.foerdern-und-stiften.uni-mainz.de/files/2021/09/foerdern-und-stiften_2021_1_web.pdf',
#  'http://www.foerdern-und-stiften.uni-mainz.de/1782.php',
#  'http://www.foerdern-und-stiften.uni-mainz.de/1782.php',
#  'http://www.foerdern-und-stiften.uni-mainz.de/1782.php',
#  'http://www.foerdern-und-stiften.uni-mainz.de/',
#  'https://forschung.uni-mainz.de/transfer/',
#  'https://forschung.uni-mainz.de/transfer/',
#  'https://forschung.uni-mainz.de/transfer/',
#  'https://www.wissenschaftsallianz-mainz.de/',
#  'https://www.wissenschaftsallianz-mainz.de/',
#  'https://www.wissenschaftsallianz-mainz.de/',
#  'https://www.fuer-unternehmen.uni-mainz.de/',
#  'http://www.fuer-unternehmen.uni-mainz.de/',
#  'http://www.fuer-unternehmen.uni-mainz.de/',
#  'http://www.fuer-unternehmen.uni-mainz.de/',
#  'https://www.zq.uni-mainz.de/',
#  'https://www.zq.uni-mainz.de/',
#  'https://www.zq.uni-mainz.de/',
#  'https://www.fuer-unternehmen.uni-mainz.de/',
#  'https://www.career.uni-mainz.de',
#  'https://www.career.uni-mainz.de',
#  'https://www.career.uni-mainz.de',
#  'https://www.foerdern-und-stiften.uni-mainz.de',
#  'https://www.foerdern-und-stiften.uni-mainz.de',
#  'https://www.foerdern-und-stiften.uni-mainz.de',
#  'https://www.fuer-unternehmen.uni-mainz.de/',
#  'https://download.uni-mainz.de/presse/P_statement_ukraine.pdf',
#  'https://download.uni-mainz.de/presse/P_statement_ukraine.pdf',
#  'https://download.uni-mainz.de/presse/P_statement_ukraine.pdf',
#  'https://www.uni-mainz.de/presse/aktuell/15209_DEU_HTML.php',
#  'https://www.uni-mainz.de/presse/aktuell/15209_DEU_HTML.php',
#  'https://www.uni-mainz.de/presse/aktuell/15209_DEU_HTML.php',
#  'https://www.uni-mainz.de/presse/aktuell/32_DEU_HTML.php',
#  'https://www.uni-mainz.de/presse/aktuell/15168_DEU_HTML.php',
#  'https://www.uni-mainz.de/presse/aktuell/15168_DEU_HTML.php',
#  'https://www.uni-mainz.de/presse/aktuell/15168_DEU_HTML.php',
#  'https://www.uni-mainz.de/presse/aktuell/15135_DEU_HTML.php',
#  'https://www.uni-mainz.de/presse/aktuell/15135_DEU_HTML.php',
#  'https://www.uni-mainz.de/presse/aktuell/15135_DEU_HTML.php',
#  'https://www.uni-mainz.de/pressemitteilungen',
#  'https://www.uni-mainz.de/presse/aktuell/15142_DEU_HTML.php',
#  'https://www.uni-mainz.de/presse/aktuell/15142_DEU_HTML.php',
#  'https://www.uni-mainz.de/presse/aktuell/15142_DEU_HTML.php',
#  'https://corona.uni-mainz.de/',
#  'https://corona.uni-mainz.de/',
#  'https://corona.uni-mainz.de/',
#  'https://www.uni-mainz.de/presse/',
#  'https://www.magazin.uni-mainz.de/12391_DEU_HTML.php',
#  'https://www.magazin.uni-mainz.de/12391_DEU_HTML.php',
#  'https://www.magazin.uni-mainz.de/12391_DEU_HTML.php',
#  'https://forschungsprofil.uni-mainz.de/weitere-verbundprojekte/',
#  'https://www.forthem-alliance.eu/',
#  'https://www.german-u15.de/',
#  'https://www.rhein-main-universitaeten.de/',
#  'https://www.wissenschaftsallianz-mainz.de/',
#  'https://www.hrk.de/weltoffene-hochschulen',
#  'http://www.facebook.com/unimainz',
#  'http://twitter.com/uni_mainz',
#  '/32.php',
#  'http://www.youtube.com/universitaetmainz',
#  '/144.php',
#  'http://www.uni-mainz.de/impressum',
#  'https://www.uni-mainz.de/barrierefreiheit',
#  '#page_start']

# %% [markdown]
# # Markup Probleme

# %% [markdown]
# ![Tags](http://imgs.xkcd.com/comics/tags.png )

# %% [markdown]
# ## Unterschiedliche Parsing Bibliotheken
#
# BeautifulSoup unterstützt verschiedene parsing libraries, diese unterscheiden sich sowohl in der Geschwindigkeit als auch in der Art und Weise in der sie Fehler behandeln. Ein Vergleich verschiedener Parser findet sich [hier](http://www.crummy.com/software/BeautifulSoup/bs4/doc/#installing-a-parser).

# %%
# Default html.parser
# (On my machine lxml is the default setting)

BeautifulSoup('<a></p>', 'html.parser')
# Out:
# <a></a>

# %%
# lxml
BeautifulSoup('<a></p>', 'lxml')
# Out:
# <html><body><a></a></body></html>

# %%
# lxml xml
BeautifulSoup('<a></p>', 'xml')
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <a/>

# %%
# html5lib (parses like a webbrowser)
BeautifulSoup('<a></p>', 'html5lib')
# Out:
# <html><head></head><body><a><p></p></a></body></html>

# %% [markdown]
# ## Beispiel
#
# Liste der Mitglieder im Verein der Bayrischen Landtagspresse: [https://landtagspresse.de/mitglieder/](https://landtagspresse.de/mitglieder/)

# %%
from urllib.request import urlopen

def soupify(url, features='html5lib'):
    """Takes a URL, requests it and parses it through BeautifulSoup."""
    with urlopen('https://blog.soziologie.de/') as response:
        html = response.read()
    soup = BeautifulSoup(html, features=features)
    return soup

# %% [markdown]
# # Webcrawling

# %% [markdown]
# ## Kriechen, aber richtig
#
# 1. Basis-URL festlegen (*seed*).
# 2. Weiterführende Links identifizieren (*crawl frontier*).
# 3. Regeln zur Auswahl spezifischer Hyperlinks (*policies*).
#
# Dieser Vorgang wird rekursiv gemacht indem die ausgewählten Links als Ausgangslage für den nächsten Crawlvorgang herangezogen werden.

# %% [markdown]
# ## Benimmregeln
#
# Immer mit der Rechtslage des jeweiligen Landes (eigener Standort und Server) vertraut sein! Unbedingt die Terms of Service beachten!
#
# Zusätzlich:
#
# * Nur so viel, wie man braucht!
# * Crawlzeiten sollten möglichst an die Bedürfnisse des Servers und der jeweiligen Community angepasst sein. Ruhezeiten sollten eingeplant werden.
# * Reduktion der Serverlast soweit wie möglich!
# * Anständig bleiben! Belästigung oder Schaden für die Nutzer des Webdienstes sollten unbedingt vermieden werden.
# * Privatsphäre achten!

# %% [markdown]
# ## Beispiel
#
# [SozBlog Archiv](https://blog.soziologie.de/archiv/) crawlen oder ...?
