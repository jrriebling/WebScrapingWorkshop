# %% [markdown]
# **Web Scraping und Data Mining in Python**
#
# # Webscraping and Webcrawling
#
#
# Jan Riebling, *Universität Wuppertal*

# %% [markdown]
# # Einführung ins web scraping

# %% [markdown]
# ## Screen scraping
#
# Daten vom Bildschirm „abkratzen“, d.h. Daten die dem Nutzer angezeigt werden. Da von Browsern dargestellte HTML-Dokumente eine der meistgenutzten Datenquellen sind, spricht man auch vom „web scraping“.

# %% [markdown]
# ## Downloading
#
# Python 3's `urllib` Modul stellt Funktionen und Klassen für das Öffnen und Herunterladen von Online-Ressourcen bereit. Ein tieferer Einblick findet sich in der Python Dokumentation und dem darin enthaltenen [How To](https://docs.python.org/3/howto/urllib2.html).

# %%
import urllib

url = 'https://www.uni-mainz.de/'

# To be on the safe side:
with urllib.request.urlopen(url) as response:
    html = response.read()

# %%
print(html[:1500])
# Out:
# b'<!DOCTYPE html>\r\n<html dir="ltr" lang="de">\r\n   <head>\r\n      <meta charset="utf-8">\r\n      <meta http-equiv="X-UA-Compatible" content="IE=edge">\r\n      <meta name="viewport" content="width=device-width, initial-scale=1.0">      <meta name="author" content="Johannes Gutenberg-Universit\xc3\xa4t Mainz">\r\n      <meta name="description" content="Die Johannes Gutenberg-Universit\xc3\xa4t Mainz z\xc3\xa4hlt mit rund 33.000 Studierenden aus \xc3\xbcber 130 Nationen zu den zehn gr\xc3\xb6\xc3\x9ften Universit\xc3\xa4ten Deutschlands. Als einzige Volluniversit\xc3\xa4t in Rheinland-Pfalz vereint sie nahezu alle akademischen Disziplinen.">\r\n      <meta name="page_id" content="2">\r\n      <meta name="copyright" content="Johannes Gutenberg-Universit\xc3\xa4t Mainz">\r\n      <meta name="Linktitle" content="">\r\n      <meta name="keywords" content="">\r\n      <meta name="robots" content="index, follow, noarchive">\r\n      <meta name="generator" content="">\r\n      <title>\r\n         Willkommen an der JGU!\r\n      </title>\r\n      <link rel="shortcut icon" href="/Illustrationen/favicon.ico">\r\n      <link rel="icon" href="/Illustrationen/favicon.ico"><link rel="canonical" href="http://www.uni-mainz.de/index.php">\r\n      <!-- CSS-Base-URL ist css.uni-mainz.de -->\r\n      <link href="//css.uni-mainz.de/css/jgu_style.min.css?v=1571842591" rel="stylesheet">\r\n      <!--[if lt IE 9]>\r\n        <script src="//css.uni-mainz.de/js/html5shiv.min.js"></script>\r\n        <script src="//css.uni-mainz.de/js/respond.min.js"></script>\r\n      <![endif]-->\r\n      <script s'

# %% [markdown]
# ## Hypertext Markup Language
#
# Beschreibt die Semantik eines HTML-Dokuments. Besteht aus einem *Baum* einzelner HTML-Elemente. Jedes Element besteht aus drei Teilen:
#
# ```html
# <a href="https://www.wikipedia.org/">A link to Wikipedia!</a>
# ```
#
# 1. Die *Tags*, die das Element eröffnen und schließen.
# 2. Die *Attribute* des Elements, die sich innerhalb des eröffnenden Tags finden.
# 3. Der *Text* der „marked up“ werden soll.

# %% [markdown]
# <a href="https://www.wikipedia.org/">A link to Wikipedia!</a>

# %% [markdown]
# ## HTML Tags
#
# [Liste von HTML tags](https://www.w3schools.com/tags/default.asp)

# %% [markdown]
# # BeautifulSoup

# %% [markdown]
# ## Parsing HTML
#
# Der Vorgang des Analysierens und Prozessierens einer Zeichenkette nach den Regeln einer formalen Grammatik. Das resultierende Objekt ist meistens eine hierarchische Repräsentation des Strings in Form eines Baumgraphens.

# %% [markdown]
# ## Wie?
#
# BeautifulSoup ist ein Python Paket, welches es erlaubt HTML und XML-Strings zu parsen und auf diese als native Python-Typen zuzugreifen. Die Dokumentation fimndet sich [hier](http://www.crummy.com/software/BeautifulSoup/bs4/doc/#).

# %%
from bs4 import BeautifulSoup

# Parsen des HTMLs der Universitäts-Webseite
soup = BeautifulSoup(html)

# %% [markdown]
# ## Den Wald vor lauter Bäumen...
#
# Bei Baum-Graphen handelt es sich um gerichtete Graphen, d.h. Knoten die mit Kantenzügen verbunden sind die eine Richtung aufweisen. Sie gehen von einem Ursprung aus (Root) und dürfen keine Kreise, im graphtheoretischen Sinne des Wortes enthalten. Ausführlichere Informationen finden sich [hier](https://en.wikipedia.org/wiki/Tree_%28data_structure%29).

# %% [markdown]
# ## Ein Baum:
#
# ![A tree](https://upload.wikimedia.org/wikipedia/commons/thumb/f/f7/Binary_tree.svg/300px-Binary_tree.svg.png)

# %% [markdown]
# ## Kein Baum:
#
# ![Not a tree](https://upload.wikimedia.org/wikipedia/commons/thumb/1/1c/Directed_graph%2C_cyclic.svg/320px-Directed_graph%2C_cyclic.svg.png)

# %% [markdown]
# ## Terminologie
#
# * **Root**: the top parent node.
# * **Parent**: node with outgoing edge relative to the child.
# * **Child**: node with incoming edge relative to the parent.
# * **Siblings**: nodes with the same parent.
# * **Descendants**: all nodes reachable from a parent node.
# * **Ancestors**: all parents of a specific child node.
#
# ![A tree](https://upload.wikimedia.org/wikipedia/commons/thumb/f/f7/Binary_tree.svg/300px-Binary_tree.svg.png)

# %% [markdown]
# ## Bäume navigieren

# %%
soup.find_all('meta')
# Out:
# [<meta charset="utf-8"/>,
#  <meta content="IE=edge" http-equiv="X-UA-Compatible"/>,
#  <meta content="width=device-width, initial-scale=1.0" name="viewport"/>,
#  <meta content="Johannes Gutenberg-Universität Mainz" name="author"/>,
#  <meta content="Die Johannes Gutenberg-Universität Mainz zählt mit rund 33.000 Studierenden aus über 130 Nationen zu den zehn größten Universitäten Deutschlands. Als einzige Volluniversität in Rheinland-Pfalz vereint sie nahezu alle akademischen Disziplinen." name="description"/>,
#  <meta content="2" name="page_id"/>,
#  <meta content="Johannes Gutenberg-Universität Mainz" name="copyright"/>,
#  <meta content="" name="Linktitle"/>,
#  <meta content="" name="keywords"/>,
#  <meta content="index, follow, noarchive" name="robots"/>,
#  <meta content="" name="generator"/>]

# %%
soup.find_all('a', href=True)
# Out:
# [<a href="//www.uni-mainz.de" target="_top"><span class="jgu_logo_image" id="jgu_logo" title="Johannes Gutenberg-Universität Mainz"></span>
#  <div class="sr-only">
#  <a href="//www.uni-mainz.de" target="_top"><span class="jgu_logo_image" id="jgu_logo" title="Johannes Gutenberg-Universität Mainz">Logo der Johannes Gutenberg-Universität Mainz</span></a>
#  </div></a>,
#  <a href="//www.uni-mainz.de" target="_top"><span class="jgu_logo_image" id="jgu_logo" title="Johannes Gutenberg-Universität Mainz">Logo der Johannes Gutenberg-Universität Mainz</span></a>,
#  <a href="/index.php"></a>,
#  <a href="//www.uni-mainz.de" target="_top"><span class="jgu_logo_small" id="jgu_logo_small" title="Johannes Gutenberg-Universität Mainz"></span>
#  <div class="sr-only">
#  <a href="//www.uni-mainz.de" target="_top"><span class="jgu_logo_small" id="jgu_logo_small" title="Johannes Gutenberg-Universität Mainz">Logo der Johannes Gutenberg-Universität Mainz</span></a>
#  </div></a>,
#  <a href="//www.uni-mainz.de" target="_top"><span class="jgu_logo_small" id="jgu_logo_small" title="Johannes Gutenberg-Universität Mainz">Logo der Johannes Gutenberg-Universität Mainz</span></a>,
#  <a accesskey="5" class="collapsed" data-target="#nav_mobile" data-toggle="collapse" href="#" title="Enter navigation"><span class="icon_mobile_nav icon_bars"><dfn class="sr-only">Navigation ein-/ausblenden</dfn></span></a>,
#  <a accesskey="1" href="/index.php" target="_top" title="Startseite dieser Website">Home</a>,
#  <a accesskey="5" data-target="#searchbar" data-toggle="collapse" href="http://www.uni-mainz.de/suche" target="_top" title="Suche">Suche</a>,
#  <a href="http://www.uni-mainz.de/kontakt" target="_top" title="Kontakt">Kontakt</a>,
#  <a href="/eng/index.php" target="_top" title="This page in English">English</a>,
#  <a class="" href="https://universitaet.uni-mainz.de" title="Über die JGU">Über die JGU</a>,
#  <a class="" href="https://organisation.uni-mainz.de" title="Organisation">Organisation</a>,
#  <a class="" href="https://fachbereiche.uni-mainz.de/" title="Fachbereiche">Fachbereiche</a>,
#  <a class="" href="https://www.studium.uni-mainz.de/" title="Studium">Studium</a>,
#  <a class="" href="https://lehre.uni-mainz.de" title="Lehre">Lehre</a>,
#  <a class="" href="https://forschungsprofil.uni-mainz.de" title="Forschung">Forschung</a>,
#  <a class="" href="https://wissenschaftliche-weiterbildung.uni-mainz.de" title="Weiterbildung">Weiterbildung</a>,
#  <a accesskey="1" href="/index.php" target="_top" title="Startseite dieser Website">Home</a>,
#  <a accesskey="5" data-target="#searchbar" data-toggle="collapse" href="http://www.uni-mainz.de/suche" target="_top" title="Suche">Suche</a>,
#  <a href="http://www.uni-mainz.de/kontakt" target="_top" title="Kontakt">Kontakt</a>,
#  <a href="/eng/index.php" target="_top" title="This page in English">English</a>,
#  <a data-toggle="tab" href="#menu2" role="tab">Site Links</a>,
#  <a class="" href="https://universitaet.uni-mainz.de" title="Über die JGU">Über die JGU</a>,
#  <a class="" href="https://organisation.uni-mainz.de" title="Organisation">Organisation</a>,
#  <a class="" href="https://fachbereiche.uni-mainz.de/" title="Fachbereiche">Fachbereiche</a>,
#  <a class="" href="https://www.studium.uni-mainz.de/" title="Studium">Studium</a>,
#  <a class="" href="https://lehre.uni-mainz.de" title="Lehre">Lehre</a>,
#  <a class="" href="https://forschungsprofil.uni-mainz.de" title="Forschung">Forschung</a>,
#  <a class="" href="https://wissenschaftliche-weiterbildung.uni-mainz.de" title="Weiterbildung">Weiterbildung</a>,
#  <a href="https://www.studium.uni-mainz.de/einfuehrungsveranstaltungen/"><img alt="Informationsangebote für Erstsemester zum Sommersemester 2022 (Grafik: artefont – Tanja Labs) ...&gt;" class="slide1" src="/Bilder_allgemein/startseite_ZSB_ersti-veranstaltungen_sose_2022_rdax_836x334.jpg"/></a>,
#  <a href="https://www.studium.uni-mainz.de/einfuehrungsveranstaltungen/">Informationsangebote für Erstsemester zum Sommersemester 2022 (Grafik: artefont – Tanja Labs) ...&gt;</a>,
#  <a href="https://www.uni-mainz.de/presse/aktuell/13679_DEU_HTML.php"><img alt="Mit dem neuen Sonderforschungsbereich TPChange unter Leitung von Prof. Dr. Peter Hoor (r.) untersucht die JGU die Bedeutung der Tropopausenregion für das Klima (Foto: Eric Lichtenscheidt)" class="slide2" data-src="/Bilder_allgemein/SFB_301_TPChange_25_Foto_Eric_Lichtenscheidt.jpg" src=""/></a>,
#  <a href="https://www.uni-mainz.de/presse/aktuell/13679_DEU_HTML.php">Mit dem neuen Sonderforschungsbereich TPChange unter Leitung von Prof. Dr. Peter Hoor (r.) untersucht die JGU die Bedeutung der Tropopausenregion für das Klima (Foto: Eric Lichtenscheidt)</a>,
#  <a href="https://www.studium.uni-mainz.de/studienwahl-podcast/"><img alt="Du bist noch auf der Suche nach dem passenden Studiengang? Dann einfach reinhören in unseren Studienwahl-Podcast!" class="slide3" data-src="/Bilder_allgemein/startseite_ZSB_studienwahlpodcast_836x334.jpg" src=""/></a>,
#  <a href="https://www.studium.uni-mainz.de/studienwahl-podcast/">Du bist noch auf der Suche nach dem passenden Studiengang? Dann einfach reinhören in unseren Studienwahl-Podcast!</a>,
#  <a href="https://gutenberg-netzwerk.uni-mainz.de/projekte/75aus75"><img alt="Lernen Sie 75 Gutenberg-Alumni aus 75 Jahren JGU kennen! (Fotos/© v.l.: HHU / Ivo Mayr, Laurence Chaperon, Stefanie Aumiller / MPG, privat, Frieder Scheuschner, privat, privat, Hwang philjoo) " class="slide4" data-src="/Bilder_allgemein/75aus75_banner_startseite_v03.jpg" src=""/></a>,
#  <a href="https://gutenberg-netzwerk.uni-mainz.de/projekte/75aus75">Lernen Sie 75 Gutenberg-Alumni aus 75 Jahren JGU kennen! (Fotos/© v.l.: HHU / Ivo Mayr, Laurence Chaperon, Stefanie Aumiller / MPG, privat, Frieder Scheuschner, privat, privat, Hwang philjoo)</a>,
#  <a class="left carousel-control carousel-control-area-left" data-slide="prev" href="#jgu_carousel_id_50" role="button"><dfn class="sr-only">Zurück</dfn></a>,
#  <a class="right carousel-control carousel-control-area-right" data-slide="next" href="#jgu_carousel_id_50" role="button"><dfn class="sr-only">Vor</dfn></a>,
#  <a href="https://jogustine.uni-mainz.de/">JOGU-StINe</a>,
#  <a href="https://personen.uni-mainz.de/">Personensuche</a>,
#  <a class="group" href="http://www.studium.uni-mainz.de/"><img alt="STUDIEREN AN DER JGU" class="right" src="/Bilder_allgemein/banner_portal_studium_190pxbreit.jpg"/><strong>STUDIEREN AN DER JGU:</strong> <nobr>250 Studiengänge</nobr> entdecken im Portal Studium</a>,
#  <a class="group" href="http://www.international.uni-mainz.de"><strong>JGU INTERNATIONAL:</strong> Global vernetzt in Wissenschaft und Forschung, Studium und Lehre</a>,
#  <a class="group" href="https://karriere.uni-mainz.de/"><strong>KARRIERE AN DER JGU:</strong> Bewerben Sie sich jetzt bei einer der größten Universitäten Deutschlands.</a>,
#  <a href="/index.php">Studieninteressierte</a>,
#  <a href="/index.php">Studierende</a>,
#  <a href="/index.php">Wiss. Nachwuchs</a>,
#  <a href="/index.php">Wissenschaftler/-innen</a>,
#  <a href="/index.php">Beschäftigte</a>,
#  <a href="/index.php">Gutenberg-Alumni</a>,
#  <a href="/index.php">Förderer</a>,
#  <a href="/index.php">Unternehmen</a>,
#  <a href="/index.php">Presse</a>,
#  <a class="bildlink" href="https://www.studium.uni-mainz.de/hochschulmessen/"><img alt="Kleines Bild" class="left" src="/Illustrationen/Studium_Messen_150x100.jpg" title="Kleines Bild"/></a>,
#  <a href="https://www.studium.uni-mainz.de/hochschulmessen/">Die JGU auf Hochschulmessen</a>,
#  <a class="detaillink" href="https://www.studium.uni-mainz.de/hochschulmessen/">mehr</a>,
#  <a class="bildlink" href="https://www.studium.uni-mainz.de/studienorientierung/"><img alt="Kleines Bild" class="left" src="/Illustrationen/studium_herbstuni_150x100.jpg" title="Kleines Bild"/></a>,
#  <a href="https://www.studium.uni-mainz.de/studienorientierung/">Angebote zur Studienorientierung</a>,
#  <a class="detaillink" href="https://www.studium.uni-mainz.de/studienorientierung/">mehr</a>,
#  <a class="listlink" href="http://www.studium.uni-mainz.de">ZUM PORTAL STUDIUM</a>,
#  <a class="bildlink" href="http://www.uni-mainz.de/studium/99_DEU_HTML.php"><img alt="Kleines Bild" class="left" src="/Illustrationen/studium_studienangebot_150x100.jpg" title="Kleines Bild"/></a>,
#  <a href="http://www.uni-mainz.de/studium/99_DEU_HTML.php">Zum Studienangebot</a>,
#  <a class="detaillink" href="http://www.uni-mainz.de/studium/99_DEU_HTML.php">mehr</a>,
#  <a class="bildlink" href="http://www.uni-mainz.de/studium/473_DEU_HTML.php"><img alt="Kleines Bild" class="left" src="/Illustrationen/studium_bewerbung_150x100.jpg" title="Kleines Bild"/></a>,
#  <a href="http://www.uni-mainz.de/studium/473_DEU_HTML.php">Bewerbung um einen Studienplatz</a>,
#  <a class="detaillink" href="http://www.uni-mainz.de/studium/473_DEU_HTML.php">mehr</a>,
#  <a class="listlink" href="http://www.uni-mainz.de/studium/index.php">ZUM PORTAL STUDIUM</a>,
#  <a class="bildlink" href="http://www.uni-mainz.de/studium/index.php"><img alt="Kleines Bild" class="left" src="/Illustrationen/studium_studierende_01_150x100.gif" title="Kleines Bild"/></a>,
#  <a href="http://www.uni-mainz.de/studium/index.php">Sie interessieren sich für ein Studium an der JGU?</a>,
#  <a class="detaillink" href="http://www.uni-mainz.de/studium/index.php">mehr</a>,
#  <a class="bildlink" href="http://www.uni-mainz.de/studium/400_DEU_HTML.php"><img alt="Kleines Bild" class="left" src="/Illustrationen/studium_beratung_01_150x100.jpg" title="Kleines Bild"/></a>,
#  <a href="http://www.uni-mainz.de/studium/400_DEU_HTML.php">Sie suchen Ansprechpartner an der JGU?</a>,
#  <a class="detaillink" href="http://www.uni-mainz.de/studium/400_DEU_HTML.php">mehr</a>,
#  <a class="listlink" href="http://www.uni-mainz.de/studium/index.php">ZUM PORTAL STUDIUM</a>,
#  <a class="bildlink" href="https://sl.uni-mainz.de/information-zum-umgang-der-jgu-mit-dem-coronavirus/"><img alt="Kleines Bild" class="left" src="/Illustrationen/studium_corona_150x100.jpg" title="Kleines Bild"/></a>,
#  <a href="https://sl.uni-mainz.de/information-zum-umgang-der-jgu-mit-dem-coronavirus/">Informationen zur Coronapandemie</a>,
#  <a class="detaillink" href="https://sl.uni-mainz.de/information-zum-umgang-der-jgu-mit-dem-coronavirus/">mehr</a>,
#  <a class="bildlink" href="https://www.studium.uni-mainz.de"><img alt="Kleines Bild" class="left" src="/Illustrationen/studium_online-bewerbung_01_150x100.jpg" title="Kleines Bild"/></a>,
#  <a href="https://www.studium.uni-mainz.de">Portal Studium</a>,
#  <a class="detaillink" href="https://www.studium.uni-mainz.de">mehr</a>,
#  <a class="listlink" href="http://www.uni-mainz.de/studium/95_DEU_HTML.php">ZUM PORTAL STUDIUM</a>,
#  <a class="bildlink" href="http://www.uni-mainz.de/studium/95_DEU_HTML.php"><img alt="Kleines Bild" class="left" src="/Illustrationen/studium_jogustine_150x100.jpg" title="Kleines Bild"/></a>,
#  <a href="http://www.uni-mainz.de/studium/95_DEU_HTML.php">Studienplanung und -organisation</a>,
#  <a class="detaillink" href="http://www.uni-mainz.de/studium/95_DEU_HTML.php">mehr</a>,
#  <a class="bildlink" href="http://www.career.uni-mainz.de/index.php"><img alt="Kleines Bild" class="left" src="/Illustrationen/studium_career_service_150x100.jpg" title="Kleines Bild"/></a>,
#  <a href="http://www.career.uni-mainz.de/index.php">Berufsorientierung</a>,
#  <a class="detaillink" href="http://www.career.uni-mainz.de/index.php">mehr</a>,
#  <a class="listlink" href="http://www.career.uni-mainz.de/index.php">ZUM PORTAL CAREER SERVICE</a>,
#  <a class="bildlink" href="http://www.uni-mainz.de/studium/400_DEU_HTML.php"><img alt="Kleines Bild" class="left" src="/Illustrationen/studium_online-bewerbung_02_150x100.jpg" title="Kleines Bild"/></a>,
#  <a href="http://www.uni-mainz.de/studium/400_DEU_HTML.php">Sie suchen Ansprechpartner an der JGU?</a>,
#  <a class="detaillink" href="http://www.uni-mainz.de/studium/400_DEU_HTML.php">mehr</a>,
#  <a class="bildlink" href="http://www.info.jogustine.uni-mainz.de/"><img alt="Kleines Bild" class="left" src="/Illustrationen/meatjgu.gif" title="Kleines Bild"/></a>,
#  <a href="http://www.info.jogustine.uni-mainz.de/">me@JGU</a>,
#  <a class="detaillink" href="http://www.info.jogustine.uni-mainz.de/">mehr</a>,
#  <a class="listlink" href="http://www.uni-mainz.de/studium/95_DEU_HTML.php">ZUM PORTAL STUDIUM</a>,
#  <a class="bildlink" href="https://www.aventis-foundation.org/wissenschaft/life-sciences-bridge-award/"></a>,
#  <a href="https://www.aventis-foundation.org/wissenschaft/life-sciences-bridge-award/">Ausschreibung der Aventis Foundation: Life Sciences Bridge Award 2022</a>,
#  <a class="detaillink" href="https://www.aventis-foundation.org/wissenschaft/life-sciences-bridge-award/">mehr</a>,
#  <a class="bildlink" href="https://grk2516.uni-mainz.de/ukraine/"></a>,
#  <a href="https://grk2516.uni-mainz.de/ukraine/">Besuchsstipendium für ukrainische Doktoranden</a>,
#  <a class="detaillink" href="https://grk2516.uni-mainz.de/ukraine/">mehr</a>,
#  <a class="listlink" href="http://www.nachwuchs.uni-mainz.de/">ZUM PORTAL FÜR DEN WISSENSCHAFTLICHEN UND KÜNSTLERISCHEN NACHWUCHS</a>,
#  <a class="bildlink" href="https://www.zq.uni-mainz.de/files/2021/12/F_A2-2_GSP-2022_Verse.pdf"></a>,
#  <a href="https://www.zq.uni-mainz.de/files/2021/12/F_A2-2_GSP-2022_Verse.pdf">Veranstaltung des General Postgraduate Program: Good Scientific Practice Workshop am 23. März von 9:30 Uhr - 16:15 Uhr und 24. März von 9:30 Uhr - 16:15 Uh:00 Uhr</a>,
#  <a class="detaillink" href="https://www.zq.uni-mainz.de/files/2021/12/F_A2-2_GSP-2022_Verse.pdf">mehr</a>,
#  <a class="bildlink" href="https://www.uni-frankfurt.de/52403217/Aktuelle_GRADE_Career_Talks"></a>,
#  <a href="https://www.uni-frankfurt.de/52403217/Aktuelle_GRADE_Career_Talks">Veranstaltung der RMU-Partneruniversität Frankfurt: "GRADE Online Karrieregespräch zum Thema: Early Career Researchers und Karrieren in der Wissenschaft " am 24. März um 17:00 Uhr</a>,
#  <a class="detaillink" href="https://www.uni-frankfurt.de/52403217/Aktuelle_GRADE_Career_Talks">mehr</a>,
#  <a class="listlink" href="http://www.nachwuchs.uni-mainz.de/">ZUM PORTAL FÜR DEN WISSENSCHAFTLICHEN UND KÜNSTLERISCHEN NACHWUCHS</a>,
#  <a class="bildlink" href="https://www.zq.uni-mainz.de/wissenschaftlicher-nachwuchs/apk/"></a>,
#  <a href="https://www.zq.uni-mainz.de/wissenschaftlicher-nachwuchs/apk/">Das Allgemeine Promotionskolleg</a>,
#  <a class="detaillink" href="https://www.zq.uni-mainz.de/wissenschaftlicher-nachwuchs/apk/">mehr</a>,
#  <a class="bildlink" href="https://gleichstellung.uni-mainz.de/programm-weiblicher-wissenschaftsnachwuchs-prowewin/"></a>,
#  <a href="https://gleichstellung.uni-mainz.de/programm-weiblicher-wissenschaftsnachwuchs-prowewin/">Programm Weiblicher Wissenschaftsnachwuchs (ProWeWin)</a>,
#  <a class="detaillink" href="https://gleichstellung.uni-mainz.de/programm-weiblicher-wissenschaftsnachwuchs-prowewin/">mehr</a>,
#  <a class="listlink" href="http://www.gnk.uni-mainz.de/">ZUM GUTENBERG NACHWUCHSKOLLEG</a>,
#  <a class="bildlink" href="https://forschung.uni-mainz.de/kontakt/"></a>,
#  <a href="https://forschung.uni-mainz.de/kontakt/">Förderberatung</a>,
#  <a class="detaillink" href="https://forschung.uni-mainz.de/kontakt/">mehr</a>,
#  <a class="bildlink" href="https://www.forschungsdaten.uni-mainz.de/"></a>,
#  <a href="https://www.forschungsdaten.uni-mainz.de/">Forschungsdaten</a>,
#  <a class="detaillink" href="https://www.forschungsdaten.uni-mainz.de/">mehr</a>,
#  <a class="listlink" href="https://forschung.uni-mainz.de/">ZUR ABTEILUNG FORSCHUNG UND TECHNOLOGIETRANSFER</a>,
#  <a class="bildlink" href="https://www.nachwuchs.uni-mainz.de/"><img alt="Kleines Bild" class="left" src="/Illustrationen/Banner_Nachwuchs_Allgemein_150x100Px.jpg" title="Kleines Bild"/></a>,
#  <a href="https://www.nachwuchs.uni-mainz.de/">Nachwuchsförderung</a>,
#  <a class="detaillink" href="https://www.nachwuchs.uni-mainz.de/">mehr</a>,
#  <a class="bildlink" href="https://forschung.uni-mainz.de/kontakt/inneruniversitaere-forschungsfoerderung/"></a>,
#  <a href="https://forschung.uni-mainz.de/kontakt/inneruniversitaere-forschungsfoerderung/">Inneruniversitäre Forschungsförderung</a>,
#  <a class="detaillink" href="https://forschung.uni-mainz.de/kontakt/inneruniversitaere-forschungsfoerderung/">mehr</a>,
#  <a class="listlink" href="https://forschung.uni-mainz.de/">ZUR ABTEILUNG FORSCHUNG UND TECHNOLOGIETRANSFER</a>,
#  <a class="bildlink" href="https://forschung.uni-mainz.de/transfer/"></a>,
#  <a href="https://forschung.uni-mainz.de/transfer/">Technologietransfer</a>,
#  <a class="detaillink" href="https://forschung.uni-mainz.de/transfer/">mehr</a>,
#  <a class="bildlink" href="https://forschung.uni-mainz.de/startup-center/"><img alt="Kleines Bild" class="left" src="/Illustrationen/Startup_Center_JGU_150x100Px.jpg" title="Kleines Bild"/></a>,
#  <a href="https://forschung.uni-mainz.de/startup-center/">Startup Center</a>,
#  <a class="detaillink" href="https://forschung.uni-mainz.de/startup-center/">mehr</a>,
#  <a class="listlink" href="https://forschung.uni-mainz.de/">ZUR ABTEILUNG FORSCHUNG UND TECHNOLOGIETRANSFER</a>,
#  <a class="bildlink" href="https://www.personalentwicklung.uni-mainz.de/programm-2"><img alt="Kleines Bild" class="left" src="/Illustrationen/fotolia_10161828_Anmelden.jpg" title="Kleines Bild"/></a>,
#  <a href="https://www.personalentwicklung.uni-mainz.de/programm-2">Personalfortbildungsprogramm 2019</a>,
#  <a class="detaillink" href="https://www.personalentwicklung.uni-mainz.de/programm-2">mehr</a>,
#  <a class="bildlink" href="https://www.personalentwicklung.uni-mainz.de/veraenderungsprozesse/jgu-leadership/"><img alt="Kleines Bild" class="left" src="/Illustrationen/fotolia_32794620.jpg" title="Kleines Bild"/></a>,
#  <a href="https://www.personalentwicklung.uni-mainz.de/veraenderungsprozesse/jgu-leadership/">weitere Angebote der Personalentwicklung</a>,
#  <a class="detaillink" href="https://www.personalentwicklung.uni-mainz.de/veraenderungsprozesse/jgu-leadership/">mehr</a>,
#  <a class="listlink" href="http://www.verwaltung.uni-mainz.de">ZUM PORTAL DER ZENTRALEN VERWALTUNG</a>,
#  <a class="bildlink" href="http://www.uni-mainz.de/organisation/27_DEU_HTML.php"></a>,
#  <a href="http://www.uni-mainz.de/organisation/27_DEU_HTML.php">Die Zentrale Verwaltung der JGU</a>,
#  <a class="detaillink" href="http://www.uni-mainz.de/organisation/27_DEU_HTML.php">mehr</a>,
#  <a class="bildlink" href="http://www.familienservice.uni-mainz.de/"><img alt="Kleines Bild" class="left" src="/Illustrationen/logo_familienservicebuero_110_75.jpg" title="Kleines Bild"/></a>,
#  <a href="http://www.familienservice.uni-mainz.de/">Familien-Servicebüro</a>,
#  <a class="detaillink" href="http://www.familienservice.uni-mainz.de/">mehr</a>,
#  <a class="listlink" href="http://www.verwaltung.uni-mainz.de">ZUM PORTAL DER ZENTRALEN VERWALTUNG</a>,
#  <a class="bildlink" href="http://www.studium.uni-mainz.de/fristen-und-termine/"><img alt="Kleines Bild" class="left" src="/Illustrationen/kalenderblaetter_150x100.jpg" title="Kleines Bild"/></a>,
#  <a href="http://www.studium.uni-mainz.de/fristen-und-termine/">Fristen und Termine</a>,
#  <a class="detaillink" href="http://www.studium.uni-mainz.de/fristen-und-termine/">mehr</a>,
#  <a class="bildlink" href="http://www.uni-mainz.de/downloads/JGU_leitlinien_guter_arbeit.pdf"><img alt="Kleines Bild" class="left" src="/Illustrationen/fotolia_49139982.jpg" title="Kleines Bild"/></a>,
#  <a href="http://www.uni-mainz.de/downloads/JGU_leitlinien_guter_arbeit.pdf">Leitlinien guter Arbeit der JGU</a>,
#  <a class="detaillink" href="http://www.uni-mainz.de/downloads/JGU_leitlinien_guter_arbeit.pdf">mehr</a>,
#  <a class="listlink" href="http://www.verwaltung.uni-mainz.de">ZUM PORTAL DER ZENTRALEN VERWALTUNG</a>,
#  <a class="bildlink" href="http://www.alumni.uni-mainz.de/index.php"><img alt="Kleines Bild" class="left" src="/Illustrationen/JGU_georg_krausch_foto_JANA_kay_150x100.jpg" title="Kleines Bild"/></a>,
#  <a href="http://www.alumni.uni-mainz.de/index.php">...an Ihrer Universität!</a>,
#  <a class="detaillink" href="http://www.alumni.uni-mainz.de/index.php">mehr</a>,
#  <a class="bildlink" href="https://gutenberg-netzwerk.uni-mainz.de/registrierung/"><img alt="Kleines Bild" class="left" src="/Illustrationen/alumni_1_hover_150x100.jpg" title="Kleines Bild"/></a>,
#  <a href="https://gutenberg-netzwerk.uni-mainz.de/registrierung/">Registrieren Sie sich im Gutenberg-Netzwerk - wir freuen uns auf Sie!</a>,
#  <a class="detaillink" href="https://gutenberg-netzwerk.uni-mainz.de/registrierung/">mehr</a>,
#  <a class="listlink" href="https://gutenberg-netzwerk.uni-mainz.de/">ZUM GUTENBERG-NETZWERK</a>,
#  <a class="bildlink" href="https://gutenberg-netzwerk.uni-mainz.de/angebote/alumnicard/"><img alt="Kleines Bild" class="left" src="/Illustrationen/150x100_alumnicard.jpg" title="Kleines Bild"/></a>,
#  <a href="https://gutenberg-netzwerk.uni-mainz.de/angebote/alumnicard/">Mainzer AlumniCard</a>,
#  <a class="detaillink" href="https://gutenberg-netzwerk.uni-mainz.de/angebote/alumnicard/">mehr</a>,
#  <a class="bildlink" href="https://gutenberg-netzwerk.uni-mainz.de/alumniback/"><img alt="Kleines Bild" class="left" src="/Illustrationen/alumni_adorf_portrait_150x100.jpg" title="Kleines Bild"/></a>,
#  <a href="https://gutenberg-netzwerk.uni-mainz.de/alumniback/">Momentaufnahme</a>,
#  <a class="detaillink" href="https://gutenberg-netzwerk.uni-mainz.de/alumniback/">mehr</a>,
#  <a class="listlink" href="https://gutenberg-netzwerk.uni-mainz.de/">ZUM GUTENBERG-NETZWERK</a>,
#  <a class="bildlink" href="https://gutenberg-netzwerk.uni-mainz.de/netzwerk/initiativen/"><img alt="Kleines Bild" class="left" src="/Illustrationen/alumni_5_hover_150x100.jpg" title="Kleines Bild"/></a>,
#  <a href="https://gutenberg-netzwerk.uni-mainz.de/netzwerk/initiativen/">Initiativen und Vereine an der JGU</a>,
#  <a class="detaillink" href="https://gutenberg-netzwerk.uni-mainz.de/netzwerk/initiativen/">mehr</a>,
#  <a class="bildlink" href="https://gutenberg-netzwerk.uni-mainz.de/gruppen/alumnibeauftragte/"><img alt="Kleines Bild" class="left" src="/Illustrationen/alumni_service_Fotolia_64983299_L.jpg" title="Kleines Bild"/></a>,
#  <a href="https://gutenberg-netzwerk.uni-mainz.de/gruppen/alumnibeauftragte/">Für Alumni-Beauftragte und Vereine</a>,
#  <a class="detaillink" href="https://gutenberg-netzwerk.uni-mainz.de/gruppen/alumnibeauftragte/">mehr</a>,
#  <a class="listlink" href="https://gutenberg-netzwerk.uni-mainz.de/">ZUM GUTENBERG-NETZWERK</a>,
#  <a class="bildlink" href="http://www.foerdern-und-stiften.uni-mainz.de/1776.php"><img alt="Kleines Bild" class="left" src="/Illustrationen/logo_JGU_universitaetsstiftung_150x100.jpg" title="Kleines Bild"/></a>,
#  <a href="http://www.foerdern-und-stiften.uni-mainz.de/1776.php">Gestalten Sie die Zukunft mit der Johannes Gutenberg-Universitätsstiftung</a>,
#  <a class="detaillink" href="http://www.foerdern-und-stiften.uni-mainz.de/1776.php">mehr</a>,
#  <a class="bildlink" href="http://www.foerdern-und-stiften.uni-mainz.de/717.php"></a>,
#  <a href="http://www.foerdern-und-stiften.uni-mainz.de/717.php">Ihre Fördermöglichkeiten auf einen Blick</a>,
#  <a class="detaillink" href="http://www.foerdern-und-stiften.uni-mainz.de/717.php">mehr</a>,
#  <a class="listlink" href="http://www.foerdern-und-stiften.uni-mainz.de/">ZUM PORTAL FÖRDERN UND STIFTEN</a>,
#  <a class="bildlink" href="http://www.foerdern-und-stiften.uni-mainz.de/966.php"><img alt="Kleines Bild" class="left" src="/Illustrationen/logo_deutschlandstipendium_150x100.jpg" title="Kleines Bild"/></a>,
#  <a href="http://www.foerdern-und-stiften.uni-mainz.de/966.php">Gemeinsam junge Talente fördern</a>,
#  <a class="detaillink" href="http://www.foerdern-und-stiften.uni-mainz.de/966.php">mehr</a>,
#  <a class="bildlink" href="https://www.uni-mainz.de/presse/aktuell/12182_DEU_HTML.php"><img alt="Kleines Bild" class="left" src="/Illustrationen/Qualitaetssiegel-09-2023_100x100.jpg" title="Kleines Bild"/></a>,
#  <a href="https://www.uni-mainz.de/presse/aktuell/12182_DEU_HTML.php">JGU erhält Qualitätssiegel für gute Treuhandstiftungsverwaltung des Bundesverbands Deutscher Stiftungen</a>,
#  <a class="detaillink" href="https://www.uni-mainz.de/presse/aktuell/12182_DEU_HTML.php">mehr</a>,
#  <a class="listlink" href="http://www.foerdern-und-stiften.uni-mainz.de/">ZUM PORTAL FÖRDERN UND STIFTEN</a>,
#  <a class="bildlink" href="https://www.foerdern-und-stiften.uni-mainz.de/files/2021/09/foerdern-und-stiften_2021_1_web.pdf"><img alt="Kleines Bild" class="left" src="/Illustrationen/foerdern-und-stiften_2021_01_thumbnail.jpg" title="Kleines Bild"/></a>,
#  <a href="https://www.foerdern-und-stiften.uni-mainz.de/files/2021/09/foerdern-und-stiften_2021_1_web.pdf">Fördern und Stiften an der JGU</a>,
#  <a class="detaillink" href="https://www.foerdern-und-stiften.uni-mainz.de/files/2021/09/foerdern-und-stiften_2021_1_web.pdf">mehr</a>,
#  <a class="bildlink" href="http://www.foerdern-und-stiften.uni-mainz.de/1782.php"></a>,
#  <a href="http://www.foerdern-und-stiften.uni-mainz.de/1782.php">Haben Sie Fragen?</a>,
#  <a class="detaillink" href="http://www.foerdern-und-stiften.uni-mainz.de/1782.php">mehr</a>,
#  <a class="listlink" href="http://www.foerdern-und-stiften.uni-mainz.de/">ZUM PORTAL FÖRDERN UND STIFTEN</a>,
#  <a class="bildlink" href="https://forschung.uni-mainz.de/transfer/"></a>,
#  <a href="https://forschung.uni-mainz.de/transfer/">Wissens- und Technologietransfer</a>,
#  <a class="detaillink" href="https://forschung.uni-mainz.de/transfer/">mehr</a>,
#  <a class="bildlink" href="https://www.wissenschaftsallianz-mainz.de/"><img alt="Externer Link" class="left" src="/Illustrationen/logo_MWA_150x100_weiss.jpg" title="Externer Link"/></a>,
#  <a href="https://www.wissenschaftsallianz-mainz.de/">Mainzer Wissenschaftsallianz</a>,
#  <a class="detaillink" href="https://www.wissenschaftsallianz-mainz.de/">mehr</a>,
#  <a class="listlink" href="https://www.fuer-unternehmen.uni-mainz.de/">ZUM PORTAL FÜR UNTERNEHMEN</a>,
#  <a class="bildlink" href="http://www.fuer-unternehmen.uni-mainz.de/"></a>,
#  <a href="http://www.fuer-unternehmen.uni-mainz.de/">Zentrum für Wissenschaftliche Weiterbildung</a>,
#  <a class="detaillink" href="http://www.fuer-unternehmen.uni-mainz.de/">mehr</a>,
#  <a class="bildlink" href="https://www.zq.uni-mainz.de/"><img alt="Kleines Bild" class="left" src="/Illustrationen/logo_ZQ_150x100.jpg" title="Kleines Bild"/></a>,
#  <a href="https://www.zq.uni-mainz.de/">Zentrum für Qualitätssicherung und -entwicklung</a>,
#  <a class="detaillink" href="https://www.zq.uni-mainz.de/">mehr</a>,
#  <a class="listlink" href="https://www.fuer-unternehmen.uni-mainz.de/">ZUM PORTAL FÜR UNTERNEHMEN</a>,
#  <a class="bildlink" href="https://www.career.uni-mainz.de"><img alt="Kleines Bild" class="left" src="/Illustrationen/logo_career_service_150x100.jpg" title="Kleines Bild"/></a>,
#  <a href="https://www.career.uni-mainz.de">Career Service</a>,
#  <a class="detaillink" href="https://www.career.uni-mainz.de">mehr</a>,
#  <a class="bildlink" href="https://www.foerdern-und-stiften.uni-mainz.de"></a>,
#  <a href="https://www.foerdern-und-stiften.uni-mainz.de">Fördern und Stiften</a>,
#  <a class="detaillink" href="https://www.foerdern-und-stiften.uni-mainz.de">mehr</a>,
#  <a class="listlink" href="https://www.fuer-unternehmen.uni-mainz.de/">ZUM PORTAL FÜR UNTERNEHMEN</a>,
#  <a class="bildlink" href="https://download.uni-mainz.de/presse/P_statement_ukraine.pdf"><img alt="Kleines Bild" class="left" src="/Illustrationen/flaggen_deutschland_ukraine_150x100.jpg" title="Kleines Bild"/></a>,
#  <a href="https://download.uni-mainz.de/presse/P_statement_ukraine.pdf">Die Invasion Russlands in der Ukraine hat uns alle zutiefst erschüttert und sprachlos gemacht. Wir verurteilen die durch nichts zu rechtfertigende Aggression und solidarisieren uns mit den Bewohner*innen der Ukraine, egal welcher Sprache und Nationalität.</a>,
#  <a class="detaillink" href="https://download.uni-mainz.de/presse/P_statement_ukraine.pdf">mehr</a>,
#  <a class="bildlink" href="https://www.uni-mainz.de/presse/aktuell/15209_DEU_HTML.php"><img alt="Kleines Bild" class="left" src="/Illustrationen/09_geografie_buche_baumringe_150x100.jpg" title="Kleines Bild"/></a>,
#  <a href="https://www.uni-mainz.de/presse/aktuell/15209_DEU_HTML.php">Europas Buchenwäldern droht erhebliche Gefahr durch Klimawandel</a>,
#  <a class="detaillink" href="https://www.uni-mainz.de/presse/aktuell/15209_DEU_HTML.php">mehr</a>,
#  <a class="listlink" href="https://www.uni-mainz.de/presse/aktuell/32_DEU_HTML.php">ZU DEN PRESSEMITTEILUNGEN</a>,
#  <a class="bildlink" href="https://www.uni-mainz.de/presse/aktuell/15168_DEU_HTML.php"><img alt="Kleines Bild" class="left" src="/Illustrationen/logo_ZWW_150x100.jpg" title="Kleines Bild"/></a>,
#  <a href="https://www.uni-mainz.de/presse/aktuell/15168_DEU_HTML.php">ZWW koordiniert EU-Projekt für intergenerationelles Lernen durch gesellschaftliches Engagement</a>,
#  <a class="detaillink" href="https://www.uni-mainz.de/presse/aktuell/15168_DEU_HTML.php">mehr</a>,
#  <a class="bildlink" href="https://www.uni-mainz.de/presse/aktuell/15135_DEU_HTML.php"><img alt="Kleines Bild" class="left" src="/Illustrationen/MWG_foerderbescheid_hochschulbibliotheken_digitalisierung_150x100.jpg" title="Kleines Bild"/></a>,
#  <a href="https://www.uni-mainz.de/presse/aktuell/15135_DEU_HTML.php">Digitalisierung der Hochschulbibliotheken: Wissenschaftsminister Clemens Hoch überreicht Landesförderung in Höhe von über einer Million Euro an drei rheinland-pfälzische Hochschulen</a>,
#  <a class="detaillink" href="https://www.uni-mainz.de/presse/aktuell/15135_DEU_HTML.php">mehr</a>,
#  <a class="listlink" href="https://www.uni-mainz.de/pressemitteilungen">ZU DEN PRESSEMITTEILUNGEN</a>,
#  <a class="bildlink" href="https://www.uni-mainz.de/presse/aktuell/15142_DEU_HTML.php"><img alt="Kleines Bild" class="left" src="/Illustrationen/GFK_gutenberg_research_award_2021_roebroeks_150x100.jpg" title="Kleines Bild"/></a>,
#  <a href="https://www.uni-mainz.de/presse/aktuell/15142_DEU_HTML.php">Gutenberg Research Award für Wil Roebroeks</a>,
#  <a class="detaillink" href="https://www.uni-mainz.de/presse/aktuell/15142_DEU_HTML.php">mehr</a>,
#  <a class="bildlink" href="https://corona.uni-mainz.de/"><img alt="Kleines Bild" class="left" src="/Illustrationen/logo_JGU_kasten_150x100.jpg" title="Kleines Bild"/></a>,
#  <a href="https://corona.uni-mainz.de/">Allgemeine Information zum Umgang der JGU mit der Corona-Pandemie</a>,
#  <a class="detaillink" href="https://corona.uni-mainz.de/">mehr</a>,
#  <a class="listlink" href="https://www.uni-mainz.de/presse/">IHRE ANSPRECHPARTNER IN DER STABSSTELLE KOMMUNIKATION UND PRESSE</a>,
#  <a class="bildlink" href="https://www.magazin.uni-mainz.de/12295_DEU_HTML.php" target="_blank" title="mehr lesen"><img alt="EU-FORSCHUNGSFÖRDERUNG" class="left" src="/Illustrationen/07_IAW_chitwood_zachary_250x150.jpg"/></a>,
#  <a class="more" href="https://www.magazin.uni-mainz.de/12295_DEU_HTML.php" style="color: #c1002a;" target="_blank" title="mehr lesen">Die Rolle der Mönchsrepublik Athos im Mittelalter</a>,
#  <a class="magazinlink" href="https://www.magazin.uni-mainz.de/12295_DEU_HTML.php" target="_blank" title="mehr lesen">ZUM JGU MAGAZIN</a>,
#  <a href="https://forschungsprofil.uni-mainz.de/weitere-verbundprojekte/"><img alt="" class="img_hover_opacity img_hover_size" src="/Illustrationen/logo_EU-emblem_250pxbreit.jpg" title=""/></a>,
#  <a href="https://www.forthem-alliance.eu/"><img alt=" - Externer Link" class="img_hover_opacity img_hover_size" src="/Illustrationen/logo_forthem_250pxbreit.jpg" title=" - Externer Link"/></a>,
#  <a href="https://www.german-u15.de/"><img alt=" - Externer Link" class="img_hover_opacity img_hover_size" src="/Illustrationen/logo_german_u15_150x100.jpg" title=" - Externer Link"/></a>,
#  <a href="https://www.rhein-main-universitaeten.de/"><img alt=" - Externer Link" class="img_hover_opacity img_hover_size" src="/Illustrationen/logo_RMU_250pxbreit_02.jpg" title=" - Externer Link"/></a>,
#  <a href="https://www.wissenschaftsallianz-mainz.de/"><img alt=" - Externer Link" class="img_hover_opacity img_hover_size" src="/Illustrationen/logo_mainzer_wissenschaftsallianz_250x150.jpg" title=" - Externer Link"/></a>,
#  <a href="https://www.hrk.de/weltoffene-hochschulen"><img alt=" - Externer Link" class="img_hover_opacity img_hover_size" src="/Illustrationen/logo_weltoffene_hochschulen_150x100.jpg" title=" - Externer Link"/></a>,
#  <a href="http://www.facebook.com/unimainz" title="Externer Link"><dfn class="sr-only">Facebook</dfn></a>,
#  <a href="http://twitter.com/uni_mainz" title="Externer Link"><dfn class="sr-only">Twitter</dfn></a>,
#  <a href="/32.php"><dfn class="sr-only">RSS</dfn></a>,
#  <a href="http://www.youtube.com/universitaetmainz" title="Externer Link"><dfn class="sr-only">Youtube</dfn></a>,
#  <a href="/144.php" title="Privacy">Datenschutz</a>,
#  <a accesskey="6" href="http://www.uni-mainz.de/impressum" title="Impressum">Impressum</a>,
#  <a href="https://www.uni-mainz.de/barrierefreiheit" title="Barrierefreiheit">Barrierefreiheit</a>,
#  <a href="#page_start">Zum Seitenanfang</a>]

# %%
for element in soup('meta'):
    if 'content' in element.attrs:
        print(element['content'])
# Out:
# IE=edge
# width=device-width, initial-scale=1.0
# Johannes Gutenberg-Universität Mainz
# Die Johannes Gutenberg-Universität Mainz zählt mit rund 33.000 Studierenden aus über 130 Nationen zu den zehn größten Universitäten Deutschlands. Als einzige Volluniversität in Rheinland-Pfalz vereint sie nahezu alle akademischen Disziplinen.
# 2
# Johannes Gutenberg-Universität Mainz
#
#
# index, follow, noarchive

# %% [markdown]
# ## Repräsentation von HTML durch BS4
#
# * *Tag* $\rightarrow$ Attribute eines Python-Objekts.
# * *Attribute* $\rightarrow$ Python `dict` mit dem Namen des Attributs als Schlüssel.
# * *Text* $\rightarrow$ als Attribut `.text`.

# %%
print(soup.div.text)
# Out:
# Logo der Johannes Gutenberg-Universität Mainz
#
#
#
#
#
#
# Logo der Johannes Gutenberg-Universität Mainz
#
#
#
#
#
# Navigation ein-/ausblenden
#
#
#
#
#
# Home
#
#
# Suche
#
#
# Kontakt
#
#
# English
#
#
#
#
#
#
#
# Über die JGU
#
#
# Organisation
#
#
# Fachbereiche
#
#
# Studium
#
#
# Lehre
#
#
# Forschung
#
#
# Weiterbildung
#
#
#
#
#
#
#
#
# Home
#
#
# Suche
#
#
# Kontakt
#
#
# English
#
#
#
#
#
# Site Links
#
#
#
#
#
#
#
# Über die JGU
#
#
# Organisation
#
#
# Fachbereiche
#
#
# Studium
#
#
# Lehre
#
#
# Forschung
#
#
# Weiterbildung
#
#
#
#
#
#
#
#
#
#
#
#
#
#                         Bitte beachten: zur Nutzung dieser Website empfehlen wir die Aktivierung von Javascript in Ihrem Browser.
#
#
#
#
#
#
#
# Informationsangebote für Erstsemester zum Sommersemester 2022 (Grafik: artefont – Tanja Labs) ...>
#
#
#
#
#
# Mit dem neuen Sonderforschungsbereich TPChange unter Leitung von Prof. Dr. Peter Hoor (r.) untersucht die JGU die Bedeutung der Tropopausenregion für das Klima (Foto: Eric Lichtenscheidt)
#
#
#
#
#
# Du bist noch auf der Suche nach dem passenden Studiengang? Dann einfach reinhören in unseren Studienwahl-Podcast!
#
#
#
#
#
# Lernen Sie 75 Gutenberg-Alumni aus 75 Jahren JGU kennen! (Fotos/© v.l.: HHU / Ivo Mayr, Laurence Chaperon, Stefanie Aumiller / MPG, privat, Frieder Scheuschner, privat, privat, Hwang philjoo)
#
#
#
#
# Zurück
#
#
#
#
#
# Zu Bild 'Informationsangebote für Erstsemester zum Sommersemester 2022 (Grafik: artefont – Tanja Labs) ...>'
#
#
# Zu Bild 'Mit dem neuen Sonderforschungsbereich TPChange unter Leitung von Prof. Dr. Peter Hoor (r.) untersucht die JGU die Bedeutung der Tropopausenregion für das Klima (Foto: Eric Lichtenscheidt)'
#
#
# Zu Bild 'Du bist noch auf der Suche nach dem passenden Studiengang? Dann einfach reinhören in unseren Studienwahl-Podcast!'
#
#
# Zu Bild 'Lernen Sie 75 Gutenberg-Alumni aus 75 Jahren JGU kennen! (Fotos/© v.l.: HHU / Ivo Mayr, Laurence Chaperon, Stefanie Aumiller / MPG, privat, Frieder Scheuschner, privat, privat, Hwang philjoo) '
#
#
#
#
# Vor
#
#
#
#
#
#
#
#
#
#
# Inhalte durchsuchen Suche  Los
#
#
#
#
# JOGU-StINe
#
#
# Personensuche
#
#
#
#
#
#
#                         Toplinks
#
#
#
# STUDIEREN AN DER JGU: 250 Studiengänge entdecken im Portal Studium
#
#
# JGU INTERNATIONAL: Global vernetzt in Wissenschaft und Forschung, Studium und Lehre
#
#
# KARRIERE AN DER JGU: Bewerben Sie sich jetzt bei einer der größten Universitäten Deutschlands.
#
#
#
#
#
#
#
#
#
# Studieninteressierte
#
#
# Studierende
#
#
# Wiss. Nachwuchs
#
#
# Wissenschaftler/-innen
#
#
# Beschäftigte
#
#
# Gutenberg-Alumni
#
#
# Förderer
#
#
# Unternehmen
#
#
# Presse
#
#
#
#
#
#
#
#
#
#
#                               STUDIENORIENTIERUNG
#
#
#
#
#
#
# Die JGU auf Hochschulmessen
#
#
#                               Sie möchten die JGU und ihr umfangreiches Studienangebot kennenlernen? Das Team der Zentralen Studienberatung vertritt die JGU auf zahlreichen Hochschulmessen in ganz Deutschland. Bestimmt auch in Ihrer Nähe.
#
# mehr
#
#
#
#
#
#
# Angebote zur Studienorientierung
#
#
#                               Es gibt viele Möglichkeiten, dass passende Studium für sich zu entdecken. Einige sogar direkt an der JGU.
#
# mehr
#
#
#
# ZUM PORTAL STUDIUM
#
#
#
#
#
#
#
#                               STUDIENANGEBOT & BEWERBUNG
#
#
#
#
#
#
# Zum Studienangebot
#
#
#                               Die JGU bietet mit 145 Fächern, 119 Bachelor- und 96 Masterstudiengängen eine außergewöhnlich breite Palette von Studienmöglichkeiten.
#
# mehr
#
#
#
#
#
#
# Bewerbung um einen Studienplatz
#
#
#                               Sie möchten an der JGU studieren? Prima! Hier bekommen Sie alle relevanten Informationen zum Bewerbungsverfahren.
#
# mehr
#
#
#
# ZUM PORTAL STUDIUM
#
#
#
#
#
#
#
#                               INFORMATION UND BERATUNG
#
#
#
#
#
#
# Sie interessieren sich für ein Studium an der JGU?
#
#
#                               Besuchen Sie unser PORTAL STUDIUM. Hier finden Sie Tipps zu Studienwahl, Bewerbungsverfahren und einen gelungenen Studieneinstieg.
#
# mehr
#
#
#
#
#
#
# Sie suchen Ansprechpartner an der JGU?
#
#
#                               Mit einem Studium hängen viele Fragen zusammen. Nutzen Sie diese Angebote, werden Sie aktiv und suchen Sie die Ansprechpartner/innen auf, die Ihnen bei Ihrem Anliegen weiterhelfen können. Hier finden Sie alle relevanten Informationen.
#
# mehr
#
#
#
# ZUM PORTAL STUDIUM
#
#
#
#
#
#
#
#
#
#
#
#
#                               AKTUELLES
#
#
#
#
#
#
# Informationen zur Coronapandemie
#
#
#                               Die aktuelle Entwicklung der Coronavirus-Pandemie hat weitreichende Folgen für den Lehr-, Studien- und Prüfungsbetrieb im Sommersemester 2020 an der JGU. Hier finden Sie grundlegende Informationen über Entscheidungen und Maßnahmen.
#
# mehr
#
#
#
#
#
#
# Portal Studium
#
#
#                               Hier finden Sie alle relevanten Informationen rund ums Studium.
#
# mehr
#
#
#
# ZUM PORTAL STUDIUM
#
#
#
#
#
#
#
#                               STUDIUM AN DER JGU
#
#
#
#
#
#
# Studienplanung und -organisation
#
#
#                               Sie sind Erstsemester und möchten Ihren Stundenplan zusammenstellen? Sie studieren bereits an der JGU und möchten ein Fach wechseln? Sie stehen kurz vor dem Abschluss und möchten Zusatzqualifikationen erwerben? Wir haben die Antworten auf Ihre Fragen!
#
# mehr
#
#
#
#
#
#
# Berufsorientierung
#
#
#                               Das Portal Career Service gibt Ihnen einen Überblick über die Informations-, Beratungs- und Veranstaltungsangebote verschiedener Einrichtungen an der JGU, die Sie – je nach individueller Situation – bei der Planung Ihrer beruflichen Zukunft unterstützen.
#
# mehr
#
#
#
# ZUM PORTAL CAREER SERVICE
#
#
#
#
#
#
#
#                               INFORMATION UND BERATUNG
#
#
#
#
#
#
# Sie suchen Ansprechpartner an der JGU?
#
#
#                               Mit einem Studium hängen viele Fragen zusammen. Nutzen Sie diese Angebote, werden Sie aktiv und suchen Sie die Ansprechpartner/innen auf, die Ihnen bei Ihrem Anliegen weiterhelfen können. Hier finden Sie alle relevanten Informationen.
#
# mehr
#
#
#
#
#
#
# me@JGU
#
#
#                               Dein Portal für mehr Gelassenheit im Studium
#
# mehr
#
#
#
# ZUM PORTAL STUDIUM
#
#
#
#
#
#
#
#
#
#
#
#
#                               AKTUELLES
#
#
#
#
#
#
# Ausschreibung der Aventis Foundation: Life Sciences Bridge Award 2022
#
#
#                               Der Postdoctoral Award der Aventis Foundation richtet sich an Nachwuchswissenschaftlerinnen und -wissenschaftler der Lebenswissenschaften. Der Preis ist mit individuell 100.000€ dotiert. Die Bewerbungsfrist läuft vom 01. März bis zum 30. April.
#
# mehr
#
#
#
#
#
#
# Besuchsstipendium für ukrainische Doktoranden
#
#
#                               Das Graduiertenkolleg GRK2516 bietet geförderte Stipendien für ukrainische Doktoranden an, die bereits eine Promotion auf dem Gebiet der (weichen) kondensierten Materie begonnen haben und ihr Land verlassen mussten.
#
# mehr
#
#
#
# ZUM PORTAL FÜR DEN WISSENSCHAFTLICHEN UND KÜNSTLERISCHEN NACHWUCHS
#
#
#
#
#
#
#
#                               VERANSTALTUNGEN
#
#
#
#
#
#
# Veranstaltung des General Postgraduate Program: Good Scientific Practice Workshop am 23. März von 9:30 Uhr - 16:15 Uhr und 24. März von 9:30 Uhr - 16:15 Uh:00 Uhr
#
#
#                               Das Hauptziel dieses Kurses ist es, die grundlegenden Regeln und Werte der verantwortungsvollem Umgang mit der Forschung gemäß den lokalen, nationalen und internationalen Vorschriften und Richtlinien.
#
# mehr
#
#
#
#
#
#
# Veranstaltung der RMU-Partneruniversität Frankfurt: "GRADE Online Karrieregespräch zum Thema: Early Career Researchers und Karrieren in der Wissenschaft " am 24. März um 17:00 Uhr
#
#
#                               Weniger als 10 Prozent aller Promovierten werden einmal Prof. Jedoch gibt es auch außerhalb von Professuren attraktive Karrieremöglichkeiten in der Wissenschaft. Prof. Dr. Brigitta Wolff im Gespräch über die Promotion als auch über Perspektiven danach.
#
# mehr
#
#
#
# ZUM PORTAL FÜR DEN WISSENSCHAFTLICHEN UND KÜNSTLERISCHEN NACHWUCHS
#
#
#
#
#
#
#
#                               Qualifizierung
#
#
#
#
#
#
# Das Allgemeine Promotionskolleg
#
#
#                               Von Schreibwerkstatt bis zur Karriereplanung: Das Allgemeine Promotionskolleg (APK) der JGU bietet Doktorandinnen und Doktoranden der JGU ein abwechslungsreiches Programm. Aktuell sind noch Plätze in einigen Kursen verfügbar.
#
# mehr
#
#
#
#
#
#
# Programm Weiblicher Wissenschaftsnachwuchs (ProWeWin)
#
#
#                               Das Programm Weiblicher Wissenschaftsnachwuchs (ProWeWin) hält für Nachwuchswissenschaftlerinnen in der späten Promotionsphase und PostDocs Workshopangebote zur Erlangung von wissenschaftsrelevanten Schlüsselqualifikationen vor.
#
# mehr
#
#
#
# ZUM GUTENBERG NACHWUCHSKOLLEG
#
#
#
#
#
#
#
#
#
#
#
#
#                               FORSCHUNGSFÖRDERUNG
#
#
#
#
#
#
# Förderberatung
#
#
#                               Es gibt eine Vielzahl an Möglichkeiten, Mittel für Ihre Forschung einzuwerben. Die Abteilung Forschung und Technologietransfer unterstützt Sie bei der Suche nach passenden Förderangeboten.
#
# mehr
#
#
#
#
#
#
# Forschungsdaten
#
#
#                               Das Kompetenzteam Forschungsdaten der JGU berät Sie zur Verwaltung und Veröffentlichung von Forschungsdaten sowie zu den entsprechenden Anforderungen von Drittmittelgebern.
#
# mehr
#
#
#
# ZUR ABTEILUNG FORSCHUNG UND TECHNOLOGIETRANSFER
#
#
#
#
#
#
#
#                               Forschungsförderung
#
#
#
#
#
#
# Nachwuchsförderung
#
#
#                               Die JGU betrachtet die nachhaltige Förderung des wissenschaftlichen und künstlerischen Nachwuchses als eine ihrer Kernaufgaben. Umfassende Informationen zur Nachwuchsförderung bietet sie in ihrem entsprechenden Webportal.
#
# mehr
#
#
#
#
#
#
# Inneruniversitäre Forschungsförderung
#
#
#                               Die JGU fördert eine große Bandbreite an internen Forschungsprojekten und -initiativen. Die Abteilung Forschung und Technologietransfer bietet individuelle Beratung und Unterstützung bei der Antragstellung.
#
# mehr
#
#
#
# ZUR ABTEILUNG FORSCHUNG UND TECHNOLOGIETRANSFER
#
#
#
#
#
#
#
#                               WISSENS- UND TECHNOLOGIETRANSFER
#
#
#
#
#
#
# Technologietransfer
#
#
#                               Von der Forschung in die Anwendung, von der Idee zum Unternehmen: Die Abteilung Forschung und Technologietransfer unterstützt Kooperationen von Unternehmen oder öffentlichen Einrichtungen mit Wissenschaftlerinnen und Wissenschaftlern der JGU.
#
# mehr
#
#
#
#
#
#
# Startup Center
#
#
#                               Im Startup-Center der JGU erhalten Gründungsinteressierte allgemeine Informationen und individuelle Beratung zur Unternehmensgründung.
#
# mehr
#
#
#
# ZUR ABTEILUNG FORSCHUNG UND TECHNOLOGIETRANSFER
#
#
#
#
#
#
#
#
#
#
#
#
#                               PERSONALENTWICKLUNG
#
#
#
#
#
#
# Personalfortbildungsprogramm 2019
#
#
#                               Das neue Personalfortbildungsprogramm der Personalentwicklung ist online. Wir freuen uns auf Ihre Anmeldungen.
#
# mehr
#
#
#
#
#
#
# weitere Angebote der Personalentwicklung
#
#
#                               Viele Angebote für Führungskräfte, Professor*innen und Juniorprofessor*innen, Postdocs und Mitarbeitende finden Sie auf den Seiten der Personalentwicklung.
#
# mehr
#
#
#
# ZUM PORTAL DER ZENTRALEN VERWALTUNG
#
#
#
#
#
#
#
#                               FORMULARE UND ANLAUFSTELLEN RUND UM DEN ARBEITSALLTAG
#
#
#
#
#
#
# Die Zentrale Verwaltung der JGU
#
#
#                               Als dienstleistende Einrichtung unterstützt und fördert die Zentrale Verwaltung die Beschäftigten der JGU bei der Wahrnehmung ihrer Aufgaben in Forschung, Lehre und wissenschaftlicher Weiterbildung.
#
# mehr
#
#
#
#
#
#
# Familien-Servicebüro
#
#
#                               Die Vereinbarkeit von Beruf und Familie hat einen hohen Stellenwert bei der Gewinnung exzellenter MitarbeiterInnen auf allen Qualifikationsebenen. Beratung erhalten Studierende und Beschäftigte mit Kind(ern) beim Familien-Servicebüro der JGU.
#
# mehr
#
#
#
# ZUM PORTAL DER ZENTRALEN VERWALTUNG
#
#
#
#
#
#
#
#                               Service
#
#
#
#
#
#
# Fristen und Termine
#
#
#                               Hier finden Sie einen schnellen Überblick über Vorlesungszeiten und vorlesungsfreie Zeiten.
#
# mehr
#
#
#
#
#
#
# Leitlinien guter Arbeit der JGU
#
#
#                               Die Leitlinien guter Arbeit wurden vom Senat der JGU beschlossen.
#
# mehr
#
#
#
# ZUM PORTAL DER ZENTRALEN VERWALTUNG
#
#
#
#
#
#
#
#
#
#
#
#
#                               WILLKOMMEN ZURÜCK...
#
#
#
#
#
#
# ...an Ihrer Universität!
#
#
#                               Grußwort von Präsident Univ.-Prof. Dr. Georg Krausch für Alumnae und Alumni der Johannes Gutenberg-Universität Mainz
#
# mehr
#
#
#
#
#
#
# Registrieren Sie sich im Gutenberg-Netzwerk - wir freuen uns auf Sie!
#
#
#                               Sie haben hier studiert, gelehrt, geforscht oder waren in anderen Zusammenhängen an der JGU tätig? Melden Sie sich kostenfrei im Gutenberg-Netzwerk an und halten Sie Verbindung!
#
# mehr
#
#
#
# ZUM GUTENBERG-NETZWERK
#
#
#
#
#
#
#
#                               Aktuell
#
#
#
#
#
#
# Mainzer AlumniCard
#
#
#                               Nutzen Sie Vorteilsangebote von mainzplus CITYMARKETING und der JGU für Gutenberg-Alumni
#
# mehr
#
#
#
#
#
#
# Momentaufnahme
#
#
#                               In loser Folge stellen wir JGU-Persönlichkeiten vor: Studierende, Absolventinnen und Absolventen, Lehrende und Mitarbeitende berichten aus ihrem Lebenund von aktuellen Projekten.
#
# mehr
#
#
#
# ZUM GUTENBERG-NETZWERK
#
#
#
#
#
#
#
#                               Service
#
#
#
#
#
#
# Initiativen und Vereine an der JGU
#
#
#                               Finden Sie Alumni-Initiativen oder Alumni-Vereinigungen Ihres Fachs und Freundeskreise zu Ihren persönlichen Interessensgebieten.
#
# mehr
#
#
#
#
#
#
# Für Alumni-Beauftragte und Vereine
#
#
#                               Sie sind Alumni-Beauftragte/r eines Bereichs der JGU oder eines JGU-nahen Vereins? Wir bieten Ihnen Informationen, Austausch, Werbematerialien und zahlreiche Services - nutzen Sie unsere interne Gruppe im Netzwerk und Teamweb!
#
# mehr
#
#
#
# ZUM GUTENBERG-NETZWERK
#
#
#
#
#
#
#
#
#
#
#
#
#                               FÖRDERN UND STIFTEN
#
#
#
#
#
#
# Gestalten Sie die Zukunft mit der Johannes Gutenberg-Universitätsstiftung
#
#
#                               Wir bieten Ihnen Möglichkeiten effizienten Stifterengagements gemeinsam mit der Johannes Gutenberg-Universitätsstiftung. Sprechen Sie uns einfach an.
#
# mehr
#
#
#
#
#
#
# Ihre Fördermöglichkeiten auf einen Blick
#
#
#                               Die JGU bietet Privatpersonen sowie Unternehmen, Institutionen und Stiftungen viele Möglichkeiten, ihre Verbundenheit mit der Universität Mainz auszudrücken - in Projektkooperationen, Spenden, Stiftungen oder einem Testament zugunsten der JGU.
#
# mehr
#
#
#
# ZUM PORTAL FÖRDERN UND STIFTEN
#
#
#
#
#
#
#
#                               Aktuell
#
#
#
#
#
#
# Gemeinsam junge Talente fördern
#
#
#                               Werden Sie Partner des Deutschlandstipendiums an der JGU und unterstützen Sie die Spitzenkräfte von morgen. Der Bund verdoppelt Ihren Einsatz!
#
# mehr
#
#
#
#
#                               01.10.2020
#
#
#
# JGU erhält Qualitätssiegel für gute Treuhandstiftungsverwaltung des Bundesverbands Deutscher Stiftungen
#
#
#                               Das Siegel bescheinigt dem Siegelträger eine professionelle, transparente und verantwortungsvolle Verwaltung der anvertrauten Treuhandstiftungen. Es wird in der Regel für drei Jahre an Treuhänder verliehen.
#
# mehr
#
#
#
# ZUM PORTAL FÖRDERN UND STIFTEN
#
#
#
#
#
#
#
#                               Service
#
#
#
#
#
#
# Fördern und Stiften an der JGU
#
#
#                               Ausgabe August 2021
#
# mehr
#
#
#
#
#
#
# Haben Sie Fragen?
#
#
#                               Möchten auch Sie Verantwortung übernehmen und die Zukunft mitgestalten? Wir informieren und beraten Sie gern in einem persönlichen Gespräch. Sprechen Sie uns einfach an!
#
# mehr
#
#
#
# ZUM PORTAL FÖRDERN UND STIFTEN
#
#
#
#
#
#
#
#
#
#
#
#
#                               INNOVATION UND KOOPERATION
#
#
#
#
#
#
# Wissens- und Technologietransfer
#
#
#                               Von der Forschung in die Anwendung, von der Idee zum Unternehmen: Die Abteilung Forschung und Technologietransfer unterstützt Kooperationen von Unternehmen oder öffentlichen Einrichtungen mit Wissenschaftlerinnen und Wissenschaftlern der JGU.
#
# mehr
#
#
#
#
#
#
# Mainzer Wissenschaftsallianz
#
#
#                               Die JGU ist Gründungsmitglied der Mainzer Wissenschaftsallianz, die seit 2008 das breite und hochwertige Forschungs- und Technologie-Know-how in und um Mainz repräsentiert.
#
# mehr
#
#
#
# ZUM PORTAL FÜR UNTERNEHMEN
#
#
#
#
#
#
#
#                               WEITERBILDUNG UND QUALITÄTSSICHERUNG
#
#
#
#
#
#
# Zentrum für Wissenschaftliche Weiterbildung
#
#
#                               Das Zentrum für wissenschaftliche Weiterbildung der JGU ist Ihr Ansprechpartner für die Weiterqualifizierung, insbesondere von berufstätigen Akademikerinnen und Akademikern.
#
# mehr
#
#
#
#
#
#
# Zentrum für Qualitätssicherung und -entwicklung
#
#
#                               Das Zentrum für Qualitätssicherung und -entwicklung der JGU (ZQ) führt unter anderem Projekte im Bereich der Hochschul- und Bildungsforschung sowie Evaluationen von hochschulinternen und -externen Programmen durch.
#
# mehr
#
#
#
# ZUM PORTAL FÜR UNTERNEHMEN
#
#
#
#
#
#
#
#                               FÖRDERUNG UND KARRIERE
#
#
#
#
#
#
# Career Service
#
#
#                               Der Career Service der JGU unterstützt Studierende bei der Berufsorientierung und beim Übergang in den Beruf. Unternehmen bietet er ein kostenloses Jobportal und verschiedene Veranstaltungen an, damit sie mit Studierenden in Kontakt treten können.
#
# mehr
#
#
#
#
#
#
# Fördern und Stiften
#
#
#                               Ihre Unterstützung zählt! Hier finden Sie Angebote und Möglichkeiten zur Zusammenarbeit mit der JGU im Bereich Fördern und Stiften.
#
# mehr
#
#
#
# ZUM PORTAL FÜR UNTERNEHMEN
#
#
#
#
#
#
#
#
#
#
#
#
#                               AKTUELLES
#
#
#
#
#
#
# Die Invasion Russlands in der Ukraine hat uns alle zutiefst erschüttert und sprachlos gemacht. Wir verurteilen die durch nichts zu rechtfertigende Aggression und solidarisieren uns mit den Bewohner*innen der Ukraine, egal welcher Sprache und Nationalität.
#
#
#                               Informationen zum Umgang der JGU mit den Auswirkungen des Krieges in der Ukraine / Service-Website zu Hilfsaktionen für die Ukraine eingerichtet
#
# mehr
#
#
#
#
#
#
# Europas Buchenwäldern droht erhebliche Gefahr durch Klimawandel
#
#
#                               Baumringanalysen zeigen Wachstumseinbußen in den vergangenen Jahrzehnten / Weitere, teils drastische Rückgänge vor allem in Südeuropa zu erwarten
#
# mehr
#
#
#
# ZU DEN PRESSEMITTEILUNGEN
#
#
#
#
#
#
#
#                               AKTUELLES
#
#
#
#
#
#
# ZWW koordiniert EU-Projekt für intergenerationelles Lernen durch gesellschaftliches Engagement
#
#
#                               Sechs Partnerländer "Intergenerational Digital Service Learning" beteiligt
#
# mehr
#
#
#
#
#
#
# Digitalisierung der Hochschulbibliotheken: Wissenschaftsminister Clemens Hoch überreicht Landesförderung in Höhe von über einer Million Euro an drei rheinland-pfälzische Hochschulen
#
#
#                               JGU erhält zusätzliche Mittel zur Etablierung eines virtuellen Leitsystems für ihre Bibliotheksstandorte
#
# mehr
#
#
#
# ZU DEN PRESSEMITTEILUNGEN
#
#
#
#
#
#
#
#                               AKTUELLES
#
#
#
#
#
#
# Gutenberg Research Award für Wil Roebroeks
#
#
#                               JGU vergibt ihren bedeutendsten Forschungspreis an niederländischen Archäologen
#
# mehr
#
#
#
#
#
#
# Allgemeine Information zum Umgang der JGU mit der Corona-Pandemie
#
#
#                               Die JGU ist seit dem 7. Juni 2021 wieder im eingeschränkten Regelbetrieb.
#
# mehr
#
#
#
# IHRE ANSPRECHPARTNER IN DER STABSSTELLE KOMMUNIKATION UND PRESSE
#
#
#
#
#
#
#
#
#
#
#                            Magazin
#
#
#                            EU-FORSCHUNGSFÖRDERUNG
#
#
# Die Rolle der Mönchsrepublik Athos im Mittelalter
#
#
#                            14.03.2022
#
#
#
#                               Ihm gelang es, für sein Forschungsvorhaben MAMEMS einen ERC Starting Grant einzuwerben: Dr. Zachary Chitwood vom Arbeitsbereich Byzantinistik der Johannes Gutenberg-Universität Mainz (JGU) bemühte sich um die Förderung, die nur vereinzelt für die Geistes- und Sozialwissenschaften in Anspruch genommen wird. Dabei eignen sich die Grants des Europäischen Forschungsrats hervorragend für innovative Projekte verschiedenster Art ...
#
#
#
#
#
# ZUM JGU MAGAZIN
#
#
#
#                      Kooperationen und Partner
#                   Bitte beachten: zur Nutzung dieser Website empfehlen wir die Aktivierung von Javascript in Ihrem Browser.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Zu Ansicht 0
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Zusatzinformationen zu dieser Seite
#
#
# Name der Seite: Johannes Gutenberg-Universität Mainz
#
#
#                      14.03.2022
#
#
#
#
#
# Facebook
#
#
# Twitter
#
#
# RSS
#
#
# Youtube
#
#
#
#
#
#
# (Maillink: webmaster (AT) uni-mainz (PUNKT) de)
#
#
# Datenschutz
#
#
# Impressum
#
#
# Barrierefreiheit
#
#
# Zum Seitenanfang

# %% [markdown]
# # Den Baum durchsuchen

# %% [markdown]
# ## `.find()` und`.find_all()`
#
# Diese Methoden wenden [Filter](https://www.crummy.com/software/BeautifulSoup/bs4/doc/#kinds-of-filters) auf den Baum-Graphen oder Teile davon an um bestimmte Teile des Baums als Ausgabe zu erhalten. Folgende Objekte können als Filter verwendet werden:
#
# * Strings
# * Reguläre Ausdrücke
# * Listen (Elemente mit logischem ODER verknüpft)
# * `True`
# * Funktionen

# %% [markdown]
# ## Keyword Arguments
#
# Per Standard werden Keyword (benannte Argumente) als Filter für entsprechende bennante HTML-Attribute verwendet. Der Filter gibt dann Elemente zurück bei denen das entsprechende Attribut den spezifizierten Wert aufweist.
#
# Hinweis: Das HTML-Attribut `class` kann nur über das keyword `class_` angesprochen werden!

# %%
## Beispiel alle Tags finden

set([tag.name for tag in soup.find_all(True)])
# Out:
# {'a',
#  'article',
#  'body',
#  'br',
#  'button',
#  'dfn',
#  'div',
#  'fieldset',
#  'footer',
#  'form',
#  'h2',
#  'h3',
#  'h4',
#  'h5',
#  'head',
#  'header',
#  'html',
#  'img',
#  'input',
#  'label',
#  'legend',
#  'li',
#  'link',
#  'main',
#  'meta',
#  'nav',
#  'nobr',
#  'noscript',
#  'ol',
#  'p',
#  'script',
#  'span',
#  'strong',
#  'title',
#  'ul'}

# %%
## Übung: Alle Hyperlinks finden

fopro = soupify('https://forschungsprofil.uni-mainz.de/netzwerke/')

# %%
links = fopro.find('div', class_='entry-content').find_all('li')
#links
[link.a['href'] for link in links]
# Out:
# ['https://www.imm.fraunhofer.de/',
#  'https://hi-tron.dkfz.de/',
#  'https://www.hi-mainz.de/de/',
#  'https://www.mpic.de/',
#  'https://www.mpip-mainz.mpg.de/',
#  'https://www.ibwf.de/',
#  'https://www.imb.de/',
#  'https://www.ieg-mainz.de/likecms.php',
#  'https://lir-mainz.de/home',
#  'https://web.rgzm.de/']

# %% [markdown]
# # Markup Probleme

# %% [markdown]
# ![Tags](http://imgs.xkcd.com/comics/tags.png )

# %% [markdown]
# ## Unterschiedliche Parsing Bibliotheken
#
# BeautifulSoup unterstützt verschiedene parsing libraries, diese unterscheiden sich sowohl in der Geschwindigkeit als auch in der Art und Weise in der sie Fehler behandeln. Ein Vergleich verschiedener Parser findet sich [hier](http://www.crummy.com/software/BeautifulSoup/bs4/doc/#installing-a-parser).

# %%
# Default html.parser
# (On my machine lxml is the default setting)

BeautifulSoup('<a></p>', 'html.parser')
# Out:
# <a></a>

# %%
# lxml
BeautifulSoup('<a></p>', 'lxml')
# Out:
# <html><body><a></a></body></html>

# %%
# lxml xml
BeautifulSoup('<a></p>', 'xml')
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <a/>

# %%
# html5lib (parses like a webbrowser)
BeautifulSoup('<a></p>', 'html5lib')
# Out:
# <html><head></head><body><a><p></p></a></body></html>

# %% [markdown]
# ## Beispiel
#
# Liste der Mitglieder im Verein der Bayrischen Landtagspresse: [https://landtagspresse.de/mitglieder/](https://landtagspresse.de/mitglieder/)

# %%
from urllib.request import urlopen
import re

def soupify(url, features='html5lib'):
    """Takes a URL, requests it and parses it through BeautifulSoup."""
    with urlopen(url) as response:
        html = response.read()
    soup = BeautifulSoup(html, features=features)
    return soup

# %%
## Neues Beispiel plattentest.de

base = 'https://www.plattentests.de/rezi.php?show='

urls = [base + str(i) for i in range(1,18398)]

urls
# Out:
# ['https://www.plattentests.de/rezi.php?show=18388',
#  'https://www.plattentests.de/rezi.php?show=18389',
#  'https://www.plattentests.de/rezi.php?show=18390',
#  'https://www.plattentests.de/rezi.php?show=18391',
#  'https://www.plattentests.de/rezi.php?show=18392',
#  'https://www.plattentests.de/rezi.php?show=18393',
#  'https://www.plattentests.de/rezi.php?show=18394',
#  'https://www.plattentests.de/rezi.php?show=18395',
#  'https://www.plattentests.de/rezi.php?show=18396',
#  'https://www.plattentests.de/rezi.php?show=18397']

# %%
review.p.text == 'Error: Array is empty'
# Out:
# 'Error: Array is empty'

# %%
data = []

for url in urls:
    review = soupify(url)    
    if review.p.text == 'Error: Array is empty':
        pass
    else:
        title = review.h1.text.split(' - ')
        interpreter = title[0]
        album = title[1]
        text = review.find(id='rezitext').text
        scores = review.find_all(class_=re.compile(r'^bewertung.+'))
        ptscore = scores[0].strong.text.split('/')[0]
        uscore = scores[1].strong.text.split('/')[0]
        references = review.find(id='reziref').p.find_all('a')
        reflist = [ref.text for ref in references]
        data.append((interpreter, album, text, ptscore, uscore, reflist))

# %%
import pandas as pd

cnames = ['Interpret', 'Album', 'Rezension', 'PT-Score', 'User-Score', 'Referenzen'] 

df = pd.DataFrame(data, columns=cnames)

# %%
df
# Out:
#              Interpret                   Album  \
# 0           Underworld  Everything, everything
# 1                Björk              Selmasongs
# 2            Radiohead                   Kid A
# 3    Leningrad Cowboys             Terzo mondo
# 4          Lemonbabies           Now + forever
# ..                 ...                     ...
# 193         Simon Says              Jump Start
# 194    Third Eye Blind                    Blue
# 195    Type O Negative       World coming down
# 196     Umbra Et Imago               Mea culpa
# 197       Velvet Belly                   Lucia
#
#                                              Rezension PT-Score User-Score  \
# 0    \n            Underworld, live and everything\...        8          7
# 1    \n            Mit den Ohren sehen\n           ...        9          8
# 2    \n            Kid Alptraum oder die Bedeutung ...       10          8
# 3    \n            Weltweiter Wodka-Wahnsinn\n     ...        6          7
# 4    \n            Nix für harte Jungs\n           ...        6          8
# ..                                                 ...      ...        ...
# 193  \n            Drei Streifen im Treibsand\n    ...        7          8
# 194  \n            Spielt\'s noch einmal, 3EB!\n   ...        2          7
# 195  \n            Düsteres Herbstalbum\n          ...        8          7
# 196  \n            Mozart lebt - Falco auch\n      ...        4          8
# 197  \n            Norwegen - mal anders\n         ...        5          8
#
#                                             Referenzen
# 0    [Laurent Garnier, The Future Sound Of London, ...
# 1    [Gry, Aether, Móa, Múm, Under Byen, Matmos, Co...
# 2    [Thom Yorke, Atoms For Peace, Jonny Greenwood,...
# 3    [The Blues Brothers Band, Spinal Tap, Smash Mo...
# 4              [The Bangles, Bananarama, Bandits, Pur]
# ..                                                 ...
# 193  [Life Of Agony, Deftones, Filter, Quicksand, K...
# 194  [Green Day, Blink-182, Lit, Nada Surf, Ash, We...
# 195  [Sisters Of Mercy, Paradise Lost, Depressive A...
# 196  [Joachim Witt, Knorkator, Richthofen, Das Ich,...
# 197  [Motorsheep, Bandaloop, Björk, The Cardigans, ...
#
# [198 rows x 6 columns]

# %% [markdown]
# # Webcrawling

# %% [markdown]
# ## Kriechen, aber richtig
#
# 1. Basis-URL festlegen (*seed*).
# 2. Weiterführende Links identifizieren (*crawl frontier*).
# 3. Regeln zur Auswahl spezifischer Hyperlinks (*policies*).
#
# Dieser Vorgang wird rekursiv gemacht indem die ausgewählten Links als Ausgangslage für den nächsten Crawlvorgang herangezogen werden.

# %% [markdown]
# ## Benimmregeln
#
# Immer mit der Rechtslage des jeweiligen Landes (eigener Standort und Server) vertraut sein! Unbedingt die Terms of Service beachten!
#
# Zusätzlich:
#
# * Nur so viel, wie man braucht!
# * Crawlzeiten sollten möglichst an die Bedürfnisse des Servers und der jeweiligen Community angepasst sein. Ruhezeiten sollten eingeplant werden.
# * Reduktion der Serverlast soweit wie möglich!
# * Anständig bleiben! Belästigung oder Schaden für die Nutzer des Webdienstes sollten unbedingt vermieden werden.
# * Privatsphäre achten!

# %% [markdown]
# ## Beispiel
#
# [SozBlog Archiv](https://blog.soziologie.de/archiv/) crawlen oder ...?
